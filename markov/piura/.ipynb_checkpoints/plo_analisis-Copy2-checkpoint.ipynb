# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import pandas as pd
import scipy.signal as signal
import datetime as dt

from matplotlib import cm
import matplotlib.cbook as cbook
import matplotlib.colors as colors

sys.path.append("/home/aldo/notebooks/code/")
import sxrf_download
# Out:
# WARNING: SunpyUserWarning: Importing sunpy.timeseries without its extra dependencies may result in errors.
# The following packages are not installed:
# ['cdflib>=1.3.2']
# To install sunpy with these dependencies use `pip install sunpy[timeseries]` or `pip install sunpy[all]` for all extras.
# If you installed sunpy via conda, please report this to the community channel: https://matrix.to/#/#sunpy:openastronomy.org [sunpy.util.sysinfo]

# %%
xrdata = sxrf_download.sunpy_xrf("2025-03-07", "2025-05-26")
# Out:
# Files Downloaded:   0%|          | 0/31 [00:00<?, ?file/s]

# %%
xrdata.head()
# Out:
#                      GOES-16_short  GOES-16_long  xrsa_quality  xrsb_quality
# DateTime
# 2025-03-07 00:00:00   9.493029e-09  8.161248e-07             0             0
# 2025-03-07 00:01:00   1.189827e-08  8.433024e-07             0             0
# 2025-03-07 00:02:00   1.250495e-08  8.506790e-07             0             0
# 2025-03-07 00:03:00   1.249528e-08  8.573184e-07             0             0
# 2025-03-07 00:04:00   1.236695e-08  8.720734e-07             0             0

# %%
# !ls /data/pavnet/2025/PIURA/data
# Out:
# 2025-05-27  PIU_AMPLITUDE_2025-03-07-to-2025-05-27.csv

# %%
path = "/data/pavnet/2025/PIURA/data/PIU_AMPLITUDE_2025-03-07-to-2025-05-27.csv"
path1 = "/data/pavnet/2025/PIURA/PIU_AMP_raw_2025-02-04 17:27:25-to-2025-02-12 11:37:23.csv"
path2 = "/data/pavnet/2025/PIURA/PIU_AMPLITUDE_2024-12-17-to-2025-02-02.csv"

# %%
# !ls $path2
# Out:
# 09042025  data	 data270525
# 22052025  data1  PIU_AMPLITUDE_2024-12-17-to-2025-02-02.csv

# %%
piudf = pd.read_csv(path, index_col=[0], parse_dates=True)
piudf1 = pd.read_csv(path1, index_col=[0], parse_dates=True)/2/2.5*2.2
piudf = pd.concat( (piudf1,
                    pd.read_csv(path2, index_col=[0], parse_dates=True),
                    piudf))

# %%
ax=  plt.subplot(121)
y = piudf1.loc[dt.datetime(2025,2,5):dt.datetime(2025,2,6), "NAA-filt"]/2/2.5*2.2
ax.plot(y,)
ax.set_ylim(0,3)
ax=  plt.subplot(122)
piudf.loc[dt.datetime(2025,1,30):dt.datetime(2025,1,31), "NAA-filt"].plot(ax=ax)
ax.set_xlim()
ax.set_ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
piudf.sort_index(inplace=True)
piudf.head()
# Out:
#                           NPM       NAA       NLK       NLM           NAU  \
# 2024-12-17 16:13:52  0.169706  1.963193  0.323771  0.084886  1.036404e-06
# 2024-12-17 16:14:01  0.213703  1.979329  0.330805  0.053344  1.674022e-06
# 2024-12-17 16:14:11  0.191036  2.051870  0.346596  0.059151  1.288582e-06
# 2024-12-17 16:14:21  0.212149  1.997222  0.339606  0.074497  1.293907e-06
# 2024-12-17 16:14:30  0.231599  1.939254  0.328625  0.116682  8.756659e-07
#
#                      NPM-filt  NAA-filt  NLK-filt  NLM-filt  NAU-filt
# 2024-12-17 16:13:52  0.169706  1.963193  0.323771  0.084886  0.000001
# 2024-12-17 16:14:01  0.185933  1.970289  0.330870  0.079728  0.000001
# 2024-12-17 16:14:11  0.199923  1.977153  0.337225  0.075025  0.000001
# 2024-12-17 16:14:21  0.210079  1.983465  0.342298  0.071259  0.000001
# 2024-12-17 16:14:30  0.215887  1.988791  0.345895  0.068925  0.000001

# %%
df1m = piudf.resample('1T').mean()
df1m.head(10)
# Out:
# /tmp/ipykernel_832908/3866379178.py:1: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df1m = piudf.resample('1T').mean()
#                           NPM       NAA       NLK       NLM       NAU  \
# 2024-12-17 16:13:00  0.169706  1.963193  0.323771  0.084886  0.000001
# 2024-12-17 16:14:00  0.210476  1.986528  0.345015  0.066307  0.000001
# 2024-12-17 16:15:00  0.245862  1.996783  0.353895  0.094550  0.000001
# 2024-12-17 16:16:00  0.279827  1.949722  0.347952  0.064303  0.000002
# 2024-12-17 16:17:00  0.300099  1.962116  0.353450  0.071002  0.000001
# 2024-12-17 16:18:00  0.318303  2.019849  0.340712  0.062803  0.000001
# 2024-12-17 16:19:00  0.361828  2.034719  0.375368  0.090522  0.000002
# 2024-12-17 16:20:00  0.369817  1.978832  0.343648  0.067417  0.000002
# 2024-12-17 16:21:00  0.405450  1.990944  0.352916  0.111782  0.000001
# 2024-12-17 16:22:00  0.401292  2.011317  0.358567  0.096797  0.000002
#
#                      NPM-filt  NAA-filt  NLK-filt  NLM-filt  NAU-filt
# 2024-12-17 16:13:00  0.169706  1.963193  0.323771  0.084886  0.000001
# 2024-12-17 16:14:00  0.209512  1.985893  0.343540  0.072461  0.000001
# 2024-12-17 16:15:00  0.242257  1.983740  0.354300  0.087734  0.000001
# 2024-12-17 16:16:00  0.277999  1.972980  0.349252  0.064440  0.000002
# 2024-12-17 16:17:00  0.299970  1.949255  0.353975  0.072059  0.000001
# 2024-12-17 16:18:00  0.322802  2.015124  0.338402  0.062441  0.000001
# 2024-12-17 16:19:00  0.364708  2.032150  0.377662  0.095633  0.000002
# 2024-12-17 16:20:00  0.363475  1.986896  0.339847  0.058380  0.000002
# 2024-12-17 16:21:00  0.402772  1.990837  0.351608  0.102938  0.000002
# 2024-12-17 16:22:00  0.407698  2.004048  0.366885  0.112484  0.000002

# %%
# days in data (unique)
days = np.unique(piudf.index.date)

# %%
# pivot to matrix: X(time) x Y(date)
df1m['date'] = df1m.index.date
df1m['time'] = df1m.index.time
piudfm = df1m.pivot_table(index='date', columns='time', values='NAA-filt')

# %%
piudfm
# Out:
# time        00:00:00  00:01:00  00:02:00  00:03:00  00:04:00  00:05:00  \
# date
# 2024-12-17       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-12-18  0.205158  0.252475  0.269004  0.270718  0.287352  0.312947
# 2024-12-19  0.470940  0.477089  0.508667  0.508142  0.511467  0.525414
# 2024-12-20  0.738008  0.765931  0.781949  0.827195  0.801658  0.821690
# 2024-12-21  0.269267  0.273084  0.279596  0.291113  0.291761  0.311007
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.786399  0.773204  0.776706  0.788441  0.739278  0.763044
# 2025-05-24  0.907395  0.881503  0.794884  0.875186  0.823143  0.720960
# 2025-05-25  0.849902  0.855991  0.861608  0.811205  0.840996  0.829580
# 2025-05-26  0.786170  0.719876  0.725151  0.762200  0.754704  0.754192
# 2025-05-27  0.854637  0.883027  0.887573  0.869150  0.847778  0.910949
#
# time        00:06:00  00:07:00  00:08:00  00:09:00  ...  23:50:00  23:51:00  \
# date                                                ...
# 2024-12-17       NaN       NaN       NaN       NaN  ...  0.069147  0.066400
# 2024-12-18  0.340017  0.352839  0.409128  0.397068  ...  0.258428  0.302562
# 2024-12-19  0.544064  0.568860  0.576449  0.614311  ...  0.469651  0.481538
# 2024-12-20  0.831033  0.835909  0.849309  0.875424  ...  0.180965  0.184005
# 2024-12-21  0.310753  0.310807  0.302890  0.315763  ...  0.273228  0.245604
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23  0.686884  0.723961  0.710436  0.662537  ...  0.931059  1.019005
# 2025-05-24  0.845458  0.779588  0.753729  0.803914  ...  0.913230  0.925263
# 2025-05-25  0.799267  0.857213  0.734884  0.649363  ...  0.825429  0.809287
# 2025-05-26  0.638720  0.713816  0.625014  0.557033  ...  0.984454  0.854752
# 2025-05-27  0.930237  0.840825  0.840462  0.818758  ...       NaN       NaN
#
# time        23:52:00  23:53:00  23:54:00  23:55:00  23:56:00  23:57:00  \
# date
# 2024-12-17  0.082715  0.090192  0.114470  0.124934  0.137400  0.150961
# 2024-12-18  0.276904  0.315899  0.308848  0.342470  0.388687  0.422508
# 2024-12-19  0.495209  0.551218  0.569765  0.590625  0.620570  0.652223
# 2024-12-20  0.164487  0.187262  0.177206  0.178802  0.195626  0.196011
# 2024-12-21  0.227983  0.192326  0.211231  0.169026  0.148050  0.168002
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.949443  0.935861  0.906359  0.946662  0.905027  0.875401
# 2025-05-24  0.899637  0.917233  0.917176  0.941919  0.954068  0.874870
# 2025-05-25  0.763415  0.827345  0.817716  0.813770  0.758334  0.720035
# 2025-05-26  0.883000  0.914947  0.944651  0.957272  0.924431  0.853517
# 2025-05-27       NaN       NaN       NaN       NaN       NaN       NaN
#
# time        23:58:00  23:59:00
# date
# 2024-12-17  0.179900  0.196517
# 2024-12-18  0.439835  0.476089
# 2024-12-19  0.666967  0.695801
# 2024-12-20  0.217172  0.252616
# 2024-12-21  0.193624  0.197860
# ...              ...       ...
# 2025-05-23  0.853687  0.914077
# 2025-05-24  0.883463  0.857126
# 2025-05-25  0.719308  0.803284
# 2025-05-26  0.894025  0.923356
# 2025-05-27       NaN       NaN
#
# [139 rows x 1440 columns]

# %%
piudfm
# Out:
# time        00:00:00  00:01:00  00:02:00  00:03:00  00:04:00  00:05:00  \
# date
# 2024-12-17       NaN       NaN       NaN       NaN       NaN       NaN
# 2024-12-18  0.205158  0.252475  0.269004  0.270718  0.287352  0.312947
# 2024-12-19  0.470940  0.477089  0.508667  0.508142  0.511467  0.525414
# 2024-12-20  0.738008  0.765931  0.781949  0.827195  0.801658  0.821690
# 2024-12-21  0.269267  0.273084  0.279596  0.291113  0.291761  0.311007
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.786399  0.773204  0.776706  0.788441  0.739278  0.763044
# 2025-05-24  0.907395  0.881503  0.794884  0.875186  0.823143  0.720960
# 2025-05-25  0.849902  0.855991  0.861608  0.811205  0.840996  0.829580
# 2025-05-26  0.786170  0.719876  0.725151  0.762200  0.754704  0.754192
# 2025-05-27  0.854637  0.883027  0.887573  0.869150  0.847778  0.910949
#
# time        00:06:00  00:07:00  00:08:00  00:09:00  ...  23:50:00  23:51:00  \
# date                                                ...
# 2024-12-17       NaN       NaN       NaN       NaN  ...  0.069147  0.066400
# 2024-12-18  0.340017  0.352839  0.409128  0.397068  ...  0.258428  0.302562
# 2024-12-19  0.544064  0.568860  0.576449  0.614311  ...  0.469651  0.481538
# 2024-12-20  0.831033  0.835909  0.849309  0.875424  ...  0.180965  0.184005
# 2024-12-21  0.310753  0.310807  0.302890  0.315763  ...  0.273228  0.245604
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-05-23  0.686884  0.723961  0.710436  0.662537  ...  0.931059  1.019005
# 2025-05-24  0.845458  0.779588  0.753729  0.803914  ...  0.913230  0.925263
# 2025-05-25  0.799267  0.857213  0.734884  0.649363  ...  0.825429  0.809287
# 2025-05-26  0.638720  0.713816  0.625014  0.557033  ...  0.984454  0.854752
# 2025-05-27  0.930237  0.840825  0.840462  0.818758  ...       NaN       NaN
#
# time        23:52:00  23:53:00  23:54:00  23:55:00  23:56:00  23:57:00  \
# date
# 2024-12-17  0.082715  0.090192  0.114470  0.124934  0.137400  0.150961
# 2024-12-18  0.276904  0.315899  0.308848  0.342470  0.388687  0.422508
# 2024-12-19  0.495209  0.551218  0.569765  0.590625  0.620570  0.652223
# 2024-12-20  0.164487  0.187262  0.177206  0.178802  0.195626  0.196011
# 2024-12-21  0.227983  0.192326  0.211231  0.169026  0.148050  0.168002
# ...              ...       ...       ...       ...       ...       ...
# 2025-05-23  0.949443  0.935861  0.906359  0.946662  0.905027  0.875401
# 2025-05-24  0.899637  0.917233  0.917176  0.941919  0.954068  0.874870
# 2025-05-25  0.763415  0.827345  0.817716  0.813770  0.758334  0.720035
# 2025-05-26  0.883000  0.914947  0.944651  0.957272  0.924431  0.853517
# 2025-05-27       NaN       NaN       NaN       NaN       NaN       NaN
#
# time        23:58:00  23:59:00
# date
# 2024-12-17  0.179900  0.196517
# 2024-12-18  0.439835  0.476089
# 2024-12-19  0.666967  0.695801
# 2024-12-20  0.217172  0.252616
# 2024-12-21  0.193624  0.197860
# ...              ...       ...
# 2025-05-23  0.853687  0.914077
# 2025-05-24  0.883463  0.857126
# 2025-05-25  0.719308  0.803284
# 2025-05-26  0.894025  0.923356
# 2025-05-27       NaN       NaN
#
# [139 rows x 1440 columns]

# %%
naa_mean = np.mean(piudfm.values, axis=0)
timeh = np.linspace(0,24,piudfm.shape[1])

# %%
for d in piudfm.index:
    plt.plot(timeh, piudfm.loc[d,:], color="orange", alpha=0.05)
plt.plot(timeh, naa_mean, color="darkblue")

# %%
plt.pcolormesh(timeh, piudfm.index, piudfm.values, cmap="jet")
plt.title("NAA-PIU")
plt.xlabel("Hora del día")
plt.ylabel("Fecha")
cb = plt.colorbar()
cb.set_label("Amplitude",)

#plt.ylim(dt.date(2025,4,20),dt.date(2025,4,25))

# %%
plt.figure(figsize=(6,3))
piudfm.loc[dt.date(2025,4,23), :].plot()
# Out:
# <Axes: xlabel='time'>

# %%
# amp to dB
piudfmdb = 20*np.log10(piudfm)
plt.pcolormesh(timeh, piudfmdb.index, piudfmdb.values, cmap="jet", 
               )
plt.vlines([11,22], piudfmdb.index[0],piudfmdb.index[-1],color="k", linestyle="--")
plt.title("NAA-PIU [dB]")
# Out:
# Text(0.5, 1.0, 'NAA-PIU [dB]')

# %%
nday , nmin = piudfmdb.shape

# %%
ii=0
y = piudfmdb.iloc[ii,:].values
x = timeh
ax = plt.subplot(211)
plt.plot(x,y)
pi, _ = signal.find_peaks(y, distance=20,prominence=1, width=0)
pi_dw, _ = signal.find_peaks(-y, distance=20,prominence=2)
plt.plot(x[pi],y[pi], 'rs', markerfacecolor="none")
plt.plot(x[pi_dw],y[pi_dw], 'vb', markerfacecolor="none")
plt.xlim(0,24)
ax2 = plt.subplot(212)

xrdata.loc[piudfmdb.index[ii]:piudfmdb.index[ii]+dt.timedelta(hours=24), 
"GOES-16_long"].plot(ax=ax2, color="r")

#plt.xlim(20,25)
# Out:
# <Axes: xlabel='DateTime'>

# %%
piuday = piudfmdb.loc[:, dt.time(hour=12): dt.time(hour=22)].copy()

# %%
found_peaks = []
dh = piuday.columns
for dd in piuday.index:
    y = piuday.loc[dd,:]
    pi, _ = signal.find_peaks(y, distance=20)
    h = dh[]
    found_peaks.append((piuday.columns, dd))

plt.pcolormesh(timeh, piudfmdb.index, piudfmdb.values, cmap="jet",

# %%
dfdb = 20*np.log10(df1m["NAA-filt"])

# %%
naaday = dfdb.between_time("12:00","22:00").copy()

# %%
naaday.plot()
plt.xlim(dt.date(2025,3,8),dt.date(2025,3,9))
# Out:
# (np.float64(20155.0), np.float64(20156.0))

# %%
print(f"original shape (wholetime): {naaday.shape}\nOnly day shape: {df1m.shape}")
# Out:
# original shape (wholetime): (48681,)
# Only day shape: (116640, 12)

# %%
day_peaks, _ = signal.find_peaks(naaday, distance=30,prominence=1, width=10)
pi_dw, _ = signal.find_peaks(-naaday, distance=20,prominence=2)
idx1 =  naaday.index[day_peaks]
idx2 =  naaday.index[pi_dw]
ydate = naaday.index[day_peaks].date
xtime = [t.hour + t.minute/60 for t in naaday.index[day_peaks].time]

# %%
# pivot to matrix: X(time) x Y(date)
dfday = pd.DataFrame(naaday)
# States 
# 1: fall of signal
# 2: normal
# 3: flareactive
dfday["state"] = np.ones()*2 # set default 
dfday['date'] = dfday.index.date
dfday['time'] = dfday.index.time
piudfm = dfday.pivot_table(index='date', columns='time', values='NAA-filt')

# %%
tdayh = np.linspace(12,22,piudfm.shape[1])
plt.pcolormesh(tdayh, piudfm.index, piudfm.values, cmap="jet", 
               )
plt.plot(xtime, ydate, marker="s", lw=0,markeredgecolor="blue",markerfacecolor="none")

# %%
len(xtime)
# Out:
# 140

# %%
# derivative
dnaaday = naaday.diff(3)
ax = plt.subplot(311)
naaday.plot(ax=ax)
plt.xlim(dt.date(2025,3,7),dt.date(2025,3,9))

ax = plt.subplot(312)
dnaaday.plot(ax=ax)
plt.xlim(dt.date(2025,3,7),dt.date(2025,3,9))
ax = plt.subplot(313)
xrdata["GOES-16_long"].plot(ax=ax)
ax.set_yscale("log")
plt.xlim(dt.date(2025,3,7),dt.date(2025,3,9))
plt.ylim(1e-7, 1e-3)
# Out:
# (1e-07, 0.001)

# %%
fig = plt.figure(figsize=(5,10))
n= 5
for i in range(1,n+1):
    dnaaday = naaday.diff(i)
    ax = plt.subplot(n,1,i)
    dnaaday.plot(ax=ax)
    plt.xlim(dt.date(2025,3,7),dt.date(2025,3,9))

# %%
np.concat((idx1,idx2)).shape
# Out:
# (369,)

# %%
naaday.to_csv("PIU_070325-260525_12-22h.csv")

# %%
dnaaday.to_csv("PIU__070325-260525_12-22h.csv")

# %%
df = pd.DataFrame(dnaaday)

# %%
df["state"] = 1

# %%
df
# Out:
#                      NAA-filt  state
# 2025-03-07 12:00:00       NaN      1
# 2025-03-07 12:01:00       NaN      1
# 2025-03-07 12:02:00       NaN      1
# 2025-03-07 12:03:00       NaN      1
# 2025-03-07 12:04:00       NaN      1
# ...                       ...    ...
# 2025-05-26 21:57:00 -0.599535      1
# 2025-05-26 21:58:00 -0.459017      1
# 2025-05-26 21:59:00 -1.093475      1
# 2025-05-26 22:00:00  0.019958      1
# state                1.000000      1
#
# [48682 rows x 2 columns]
