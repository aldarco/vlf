# %%
import numpy as np
import sys 
sys.path.append("/home/pavnet/processing2/dataprocessingv2/code/")
import json

# %%
import station

# %%
with open('../config_params.json', 'r') as f:
    config = json.load(f)
    #print(json.dumps(config, indent=4))

buffersize = 3600*24 # seconds in a day
#localpath = config["localdb"]
dspconfig = config["DSP"]
ftpconfig = config["RedPitaya"]
dbconfig = config["DataBase"]
Txs = dspconfig["vlf_transmitters"].keys()
ftp = station.RPftp(ftpconfig)
sproc = station.dsp(dspconfig)

spectrum = np.zeros(sproc.fft_npts)
print("VLF TX", Txs)
# Out:
#  > SFTP is up
# ['PLO_2025_05_26_19_10_45h233803__6611.txt', 'PLO_2025_05_26_19_10_46h233798__6612.txt', 'PLO_2025_05_26_19_10_47h233785__6613.txt', 'PLO_2025_05_26_19_10_48h233774__6614.txt', 'PLO_2025_05_26_19_10_49h233762__6615.txt', 'PLO_2025_05_26_19_10_50h233755__6616.txt', 'PLO_2025_05_26_19_10_51h233735__6617.txt', 'PLO_2025_05_26_19_10_52h233732__6618.txt', 'PLO_2025_05_26_19_10_53h235448__6619.txt', 'PLO_2025_05_26_19_10_54h233703__6620.txt']
# DSP Set Ok
# VLF TX dict_keys(['NPM', 'NAA', 'NLK', 'NLM', 'NAU'])

# %%
# !ls ../config*
# Out:
# ../config_params.json

# %%
available_files = [f for f in ftp.sftp.listdir(ftp.remote_path) if f not in ftp.buffer]
remote_file = ftp.remote_path +available_files[-1]
remf = ftp.sftp.open(remote_file,"+rb")

# %%
remf

# %%
remf.write("XXXX.txt")
remf.close()

# %%
import utils

# %%
s= utils.read_binary_IQ(remf)

# %%
s
# Out:
# array([[ 5.11342  , -6.911657 , -5.1555586, ..., -0.2769907, -7.2458963,
#          0.6848234],
#        [ 2.6200306,  7.082442 , -4.7463875, ...,  5.440677 , -1.2230682,
#         -7.954104 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(s[0,:2000])

# %%
f = sproc.fft_method(s[0,:]+1j*s[1,:])

# %%
fx = np.arange(sproc.fft_npts)*sproc.sampling_freq/sproc.fft_npts
plt.plot(fx,f)
#plt.xlim(20e3,27e3)

# %%
fx.shape, f.shape
# Out:
# ((32768,), (8192,))

# %%
sproc.fft_npts
# Out:
# 32768
