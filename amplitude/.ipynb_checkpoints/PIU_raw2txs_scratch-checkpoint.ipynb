# %% [markdown]
# # RAW DATA CONVERSION FROM TARGZ
# Only uses the targz files without extracting the content.
# This notebook takes the raw data fron the PAVNET VLF receiver and applies the FFT to get the spectrums, from these spectrums we track the target transmitters (VLF) and save these narrowband signals.
#
# #### Notice
# In the simplest (and best) case you only have to change the paths of data.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os

# add to path the additional modules implemented for PAVNET data analysis
sys.path.append("/home/aldo//notebooks/code")

# %% [markdown]
# # VLF TRANSMITTERS

# %%
vlf_transmitters = {
                    "NPM":21.4e3, 
                    "NAA":24.0e3, 
                    "NLK":24.8e3, 
                    "NLM":25.2e3,
                    "NAU":40.75e3
                    }

# %% [markdown]
# # Módulos

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from matplotlib import dates as mdates
import pandas as pd
from scipy import signal
from scipy.fftpack import fft, fftfreq, fftshift
import time
import tools       # codigo propio
import datetime
import itertools
from IPython.display import clear_output
from io import StringIO as strio
import tarfile

# %%
import gc
import fft_pavnet
gc.collect()
# Out:
# 8195

# %% [markdown]
# ### Plot params

# %%
plt.rcParams["figure.figsize"] = [10,7.5]
plt.rcParams["font.size"] = 16

plt.rcParams['xtick.major.size'] = 6
plt.rcParams['xtick.major.width'] = 2.5
plt.rcParams['xtick.minor.size'] = 4
plt.rcParams['xtick.minor.width'] = 2

plt.rcParams['ytick.major.size'] = 6
plt.rcParams['ytick.major.width'] = 2.5
plt.rcParams['ytick.minor.size'] = 4
plt.rcParams['ytick.minor.width'] = 2

# %%
def butter_filt(s,cutoff, fs, order=5, fc=12e3):
    #return sp.signal.butter(order, cutoff, fs=fs, btype="low", analog=False)
    sos = sp.signal.butter(order, fc, btype='hp', fs=fs, output='sos')
    filtered = sp.signal.sosfilt(sos, s)
    return filtered

# %% [markdown]
# # Processing

# %% [markdown]
# ## General parameters

# %%
sampling_freq = 50e3 # frecuencia de muestreo de la señal en la RedPitaya
Npts = 2**14  # signal length tamaño dela señal   
frames_per_file = 1  #signals per file
fft_npts = 2**12

MINSIZE_THRESHOLD = 80000

# %%
folder1 = "/data/pavnet/2025/PIURA/09042025/" # contains subfolders
# each subfolder contains a day of data
resfolder = '/'+"/".join(folder1.split("/")[:-2]) # path for outputs)
subfolders = !ls $folder1
subfolders
# Out:
# ['2025-03-06',
#  '2025-03-07',
#  '2025-03-08',
#  '2025-03-09',
#  '2025-03-10',
#  '2025-03-11',
#  '2025-03-12',
#  '2025-03-13',
#  '2025-03-14',
#  '2025-03-15',
#  '2025-03-16',
#  '2025-03-17',
#  '2025-03-18',
#  '2025-03-19']

# %%
signal_len = Npts

method ="overlap" # window or overlap

fft_npts = 2**12

povlp = 50 # %

# frequency range (band). For f0(central frequency)=20 and bw=20, the resulting spectral will span from 10 to 30 
f0 = 25e3
bw = 40e3

# no guardar espectros para salvar memoria
SAVE_SPECTRUMS = True #False
downsampling_factor = 6 # 6 samples per minute

# trim signal length
# 2**14 ~ 16k
# 2**13 ~ 8k
# 2**12 ~ 4k

# %%
# HPF
order = 21
fc = 15e3
fs = sampling_freq
sos = signal.butter(order, fc, btype='hp', fs=fs, output='sos')
hpf = signal.firwin(order, cutoff=15e3, window="flattop", fs=fs, pass_zero="highpass")
#filtered = sp.signal.sosfilt(sos, s)
plt.rcParams["font.size"]=12

fig = plt.figure(figsize=(8,3))
plt.subplot(121)
w, h = signal.freqz_sos(sos, worN=1500, fs=fs)
db = 20*np.log10(np.maximum(np.abs(h), 1e-5))
plt.plot(w, db)
plt.axvline(fc, ls="--", lw=1, color="firebrick")
plt.title(f"HPF IIR at $f={fc/1e3}$ kHz")

plt.subplot(122)
w, h = signal.freqz(hpf, fs=fs)
db = 20*np.log10(np.maximum(np.abs(h), 1e-5))


plt.plot(w, db)
plt.axvline(fc, ls="--", lw=1, color="firebrick")
plt.title(f"HPF FIR at $f={fc/1e3}$ kHz")

#plt.subplots_adjust(wspace=1)
# Out:
# Text(0.5, 1.0, 'HPF FIR at $f=15.0$ kHz')

# %%
def get_content(ftar):
    # obtener archivo de datos (TXT) contenido en el comprimido tar.gz
    tar= tarfile.open(ftar, "r:gz")
    fileout = tar.extractfile(tar.getmembers()[0])
    content = fileout.read()
    return content

# %%
time_arr = []
fftv =[]
amplitudes = {tx:[] for tx in vlf_transmitters.keys()}
freq_arr = np.arange(fft_npts)*sampling_freq/fft_npts
ftx_indexhood = []
bw = 150 

hpf = signal.firwin(51, cutoff=12e3, window="hamming", fs=sampling_freq)

for call, f in vlf_transmitters.items():
    i = np.argmin(abs(freq_arr-f))
    id_0 = np.argmin(abs(freq_arr-(f-bw/2)))
    id_f = np.argmin(abs(freq_arr-(f+bw/2)))
    ftx_indexhood.append([id_0, id_f])
    
for subfolder in subfolders:
    print("Subfolder:", subfolder)
    fnames = np.array(tools.get_fnames(folder1+subfolder, fmt=".tar.gz"))#
    print(f"# Data Files: {len(fnames)}")
    
    #file sizes
    fsize = np.array(list(map(
                            lambda x:os.path.getsize("/".join([folder1,subfolder,x])), 
                            fnames
                            )))

    print(f"Removing :\n{fnames[fsize<MINSIZE_THRESHOLD]}")
    nfiles = len(fnames)
    
    for k, f in enumerate(fnames):
    #print(f"File {f}\t {k+1} of {nfiles} processed \t -> {round((k+1)*100/nfiles, 2)} %",end="\r")
        print("File {:60s}\t {:7d} of {:7d} processed \t -> {:3.2f} %".format(f,k+1, nfiles, round((k+1)*100/nfiles, 2) ),end="\r")
        content = get_content(folder1+subfolder+"/"+f)
        st = pd.read_csv(strio(content.decode()), comment="#", header=None, sep=",")
        #filtered = sp.signal.sosfilt(sos, s)
        #st = signal.sosfilt(sos,st.values[:,0]) + 1j*signal.sosfilt(sos,st.values[:,1])  # signal IQ fmt
        st = signal.filtfilt(hpf,1,st.values[:,0]) + 1j*signal.filtfilt(hpf,1,st.values[:,1])
        # almaecnamos el tiempo en UTC : +5h
        time_arr.append(tools.get_date_from_fname(str(f)) + datetime.timedelta(hours=5))
        #print("\napplying FFT {}".format(method))
        if method == "single":
            S = fft_pavnet.fft_window(st, wlen=fft_npts,fw=signal.windows.flattop)
        elif method == "overlap":
            S = fft_pavnet.fft_overlap(st, wlen=fft_npts, wfun=signal.windows.hann, povlp=povlp)
        else:
            break
        
        if SAVE_SPECTRUMS and not k%6:
            fftv.append(S)    
        
        for k, (tx_call, tx_f) in enumerate(vlf_transmitters.items()):
            id_0, id_f = ftx_indexhood[k]
            amp_ = np.max(S[id_0:id_f],axis=0)
            amplitudes[tx_call].append(amp_)
        print("\n---")
# Out:
# Subfolder: 2025-03-06
# # Data Files: 4410
# Removing :
# ['ANTAR_RAW_2_06_03_2025_12_34_24__2.txt.tar.gz']
# File ANTAR_RAW_4096_06_03_2025_23_36_45__4096.txt.tar.gz         	       1 of    4410 processed 	 -> 0.02 %
# ---
# File ANTAR_RAW_4031_06_03_2025_23_26_14__4031.txt.tar.gz         	       2 of    4410 processed 	 -> 0.05 %
# ---
# File ANTAR_RAW_4041_06_03_2025_23_27_51__4041.txt.tar.gz         	       3 of    4410 processed 	 -> 0.07 %
# ---
# File ANTAR_RAW_2216_06_03_2025_18_33_1__2216.txt.tar.gz          	       4 of    4410 processed 	 -> 0.09 %
# ---
# File ANTAR_RAW_3426_06_03_2025_21_48_40__3426.txt.tar.gz         	       5 of    4410 processed 	 -> 0.11 %
# ---
# File ANTAR_RAW_2075_06_03_2025_18_10_11__2075.txt.tar.gz         	       6 of    4410 processed 	 -> 0.14 %
# ---
# File ANTAR_RAW_3485_06_03_2025_21_58_12__3485.txt.tar.gz         	       7 of    4410 processed 	 -> 0.16 %
# ---
# File ANTAR_RAW_665_06_03_2025_14_21_51__665.txt.tar.gz           	       8 of    4410 processed 	 -> 0.18 %
# ---
# File ANTAR_RAW_311_06_03_2025_12_17_14__311.txt.tar.gz           	       9 of    4410 processed 	 -> 0.20 %
# ---
# File ANTAR_RAW_1494_06_03_2025_16_36_7__1494.txt.tar.gz          	      10 of    4410 processed 	 -> 0.23 %
# ---
# File ANTAR_RAW_3672_06_03_2025_22_28_18__3672.txt.tar.gz         	      11 of    4410 processed 	 -> 0.25 %
# ---
# File ANTAR_RAW_1477_06_03_2025_16_33_21__1477.txt.tar.gz         	      12 of    4410 processed 	 -> 0.27 %
# ---
# File ANTAR_RAW_1764_06_03_2025_17_19_51__1764.txt.tar.gz         	      13 of    4410 processed 	 -> 0.29 %
# ---
# File ANTAR_RAW_2158_06_03_2025_18_23_37__2158.txt.tar.gz         	      14 of    4410 processed 	 -> 0.32 %
# ---
# File ANTAR_RAW_1315_06_03_2025_16_7_8__1315.txt.tar.gz           	      15 of    4410 processed 	 -> 0.34 %
# ---
# File ANTAR_RAW_1277_06_03_2025_16_0_58__1277.txt.tar.gz          	      16 of    4410 processed 	 -> 0.36 %
# ---
# File ANTAR_RAW_1157_06_03_2025_15_41_32__1157.txt.tar.gz         	      17 of    4410 processed 	 -> 0.39 %
# ---
# File ANTAR_RAW_1054_06_03_2025_15_24_50__1054.txt.tar.gz         	      18 of    4410 processed 	 -> 0.41 %
# ---
# File ANTAR_RAW_1018_06_03_2025_15_19_0__1018.txt.tar.gz          	      19 of    4410 processed 	 -> 0.43 %
# ---
# File ANTAR_RAW_2573_06_03_2025_19_30_46__2573.txt.tar.gz         	      20 of    4410 processed 	 -> 0.45 %
# ---
# File ANTAR_RAW_19975_08_03_2025_18_22_2__19975.txt.tar.gz        	     510 of    8914 processed 	 -> 5.72 %
# ---
# File ANTAR_RAW_22055_08_03_2025_23_58_4__22055.txt.tar.gz        	     511 of    8914 processed 	 -> 5.73 %
# ---
# File ANTAR_RAW_21736_08_03_2025_23_6_36__21736.txt.tar.gz        	     512 of    8914 processed 	 -> 5.74 %
# ---
# File ANTAR_RAW_13255_08_03_2025_0_16_47__13255.txt.tar.gz        	     513 of    8914 processed 	 -> 5.75 %
# ---
# File ANTAR_RAW_14438_08_03_2025_3_27_37__14438.txt.tar.gz        	     514 of    8914 processed 	 -> 5.77 %
# ---
# File ANTAR_RAW_19938_08_03_2025_18_16_3__19938.txt.tar.gz        	     515 of    8914 processed 	 -> 5.78 %
# ---
# File ANTAR_RAW_21463_08_03_2025_22_22_34__21463.txt.tar.gz       	     516 of    8914 processed 	 -> 5.79 %
# ---
# File ANTAR_RAW_19992_08_03_2025_18_24_47__19992.txt.tar.gz       	     517 of    8914 processed 	 -> 5.80 %
# ---
# File ANTAR_RAW_13796_08_03_2025_1_44_3__13796.txt.tar.gz         	     518 of    8914 processed 	 -> 5.81 %
# ---
# File ANTAR_RAW_13973_08_03_2025_2_12_38__13973.txt.tar.gz        	     519 of    8914 processed 	 -> 5.82 %
# ---
# File ANTAR_RAW_18236_08_03_2025_13_40_37__18236.txt.tar.gz       	     520 of    8914 processed 	 -> 5.83 %
# ---
# File ANTAR_RAW_21879_08_03_2025_23_29_38__21879.txt.tar.gz       	     521 of    8914 processed 	 -> 5.84 %

# %%
fftv = np.array(fftv)
print("Shape:",fftv.shape)
spectrogram = []
for _, arr in sorted(zip(time_arr, fftv)):
    spectrogram.append(arr)
# Out:
# Shape: (20046, 4096)

# %%
timex = sorted(time_arr[::downsampling_factor])
spectrogram = np.array(spectrogram)

# %%
nn=len(timex)
fmin = 18e3
fmax = 30e3
fmask = (freq_arr>fmin) & (freq_arr<fmax)
fig = plt.figure(figsize=(10,5))
plt.pcolormesh(timex[:nn], freq_arr[fmask]/1e3, spectrogram.T[fmask, 0:nn], shading="gouraud")
plt.xlabel("Time")
plt.ylabel("Frequency (kHz)")

fig.savefig(f"PIU_Spectrum_{timex[nn].date()}-to-{timex[nn].date()}.png")
plt.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[252], line 10
#       7 plt.xlabel("Time")
#       8 plt.ylabel("Frequency (kHz)")
# ---> 10 fig.savefig(f"PIU_Spectrum_{timex[nn].date()}-to-{timex[nn].date()}.png")
#      11 plt.close()
#
# IndexError: list index out of range

# %%
del fig
gc.collect()

# %%
data = pd.DataFrame(amplitudes, index=time_arr)
data.sort_index(inplace=True)

# %%
data.head()
# Out:
#                           NPM       NAA       NLK       NLM       NAU
# 2025-03-06 17:00:21  0.777341  1.692320  0.609361  0.579795  0.000009
# 2025-03-06 17:00:31  0.767992  1.795934  0.647088  0.483911  0.000009
# 2025-03-06 17:00:41  0.665142  1.932618  0.695498  0.521984  0.000010
# 2025-03-06 17:00:51  0.689199  1.946766  0.749937  0.483139  0.000010
# 2025-03-06 17:01:01  0.782117  1.971022  0.788177  0.484273  0.000008

# %%
data["NAA"].plot()
plt.xlim(datetime.datetime(2025,3,7), datetime.datetime(2025,3,8))
# Out:
# (np.float64(20154.0), np.float64(20155.0))

# %%
dfnaa = data.copy() #{"timestamp": time_arr, "value": values})

dfnaa["date"] = data.index.date
dfnaa["hour"] = data.index.hour + data.index.minute / 60 + data.index.second / 3600

pivot_table = dfnaa.pivot(index="date", columns="hour", values="NAA")

print(pivot_table)
# Out:
# hour        0.000278   0.002222   0.003056   0.005000   0.005833   0.007778   \
# date
# 2025-03-06        NaN        NaN        NaN        NaN        NaN        NaN
# 2025-03-07   0.829715        NaN   0.855188        NaN   0.933057        NaN
# 2025-03-08        NaN   0.706953        NaN   0.723478        NaN   0.768447
#
# hour        0.008611   0.010556   0.011111   0.013056   ...  23.986944  \
# date                                                    ...
# 2025-03-06        NaN        NaN        NaN        NaN  ...   0.757151
# 2025-03-07   0.888907        NaN   0.822583        NaN  ...        NaN
# 2025-03-08        NaN    0.70103        NaN   0.595147  ...        NaN
#
# hour        23.988889  23.989722  23.991667  23.992222  23.994167  23.995000  \
# date
# 2025-03-06        NaN   0.762315        NaN   0.833671        NaN   0.767021
# 2025-03-07   0.783393        NaN   0.693388        NaN   0.627035        NaN
# 2025-03-08        NaN        NaN        NaN        NaN        NaN        NaN
#
# hour        23.996944  23.997778  23.999722
# date
# 2025-03-06        NaN   0.844341        NaN
# 2025-03-07   0.756124        NaN   0.650597
# 2025-03-08        NaN        NaN        NaN
#
# [3 rows x 12447 columns]

# %%
st_ = pd.read_csv(strio(content.decode()), comment="#", header=None, sep=",")
st_ = st_.values[:,0] + 1j*st_.values[:,1]

# %%
lpf = signal.firwin(101, 0.005, fs=1/10, pass_zero="lowpass")

data_filtered = pd.DataFrame(index=data.index.values)

for tx in vlf_transmitters.keys():
    ti = time.time()
    amp_filt = signal.filtfilt(lpf,1,data[tx].values)
    data_filtered[tx+"_filt"] = amp_filt
    tf = time.time()
    print("etime: ", 1000*(tf-ti), "ms")
# Out:
# etime:  9.681940078735352 ms
# etime:  9.987354278564453 ms
# etime:  9.11855697631836 ms
# etime:  9.000539779663086 ms
# etime:  8.951902389526367 ms

# %%
import matplotlib as mpl

# %%
cmap = mpl.colormaps['jet']
nplots = np.arange(1,14,2)
cgrads = cmap(np.linspace(0.1,0.9,len(nplots)))

# %%
d1 = datetime.datetime(2025,3,7)
d2 = d1 + datetime.timedelta(days=1)
sample_db = 20*np.log10(data["NAA"].loc[d1:d2])
sample_db_filt = 20*np.log10(data_filtered["NAA_filt"].loc[d1:d2])
off = 0
nplots = np.arange(1,14,2)
cgrads = cmap(np.random.rand(len(nplots)))
for k,i in enumerate(nplots):
    d1 = datetime.datetime(2025,3,i+6)
    d2 = d1 + datetime.timedelta(days=1)
    sample_db = 20*np.log10(data["NAA"].loc[d1:d2])
    sample_db_filt = 20*np.log10(data_filtered["NAA_filt"].loc[d1:d2])
    n = len(sample_db)
    plt.plot(np.arange(n)*24/n,sample_db.values + off, marker="o", markerfacecolor="none", color="lightgray", alpha=0.5)
    plt.plot(np.arange(n)*24/n,sample_db_filt.values + off,color=cgrads[k], lw=2, label=d1)
    off += 20
plt.legend(bbox_to_anchor=[1,1])
plt.title(f"PIU VLF ")
# Out:
# Text(0.5, 1.0, 'PIU VLF ')

# %%
dfnaa = data_filtered.resample("1min").mean() #{"timestamp": time_arr, "value": values})

dfnaa["date"] = dfnaa.index.date
dfnaa["hour"] = dfnaa.index.hour + dfnaa.index.minute / 60 + dfnaa.index.second / 3600

pivot_table = dfnaa.pivot(index="date", columns="hour", values="NAA_filt")

pivot_table.head()
# Out:
# hour        0.000000   0.016667   0.033333   0.050000   0.066667   0.083333   \
# date
# 2025-03-06        NaN        NaN        NaN        NaN        NaN        NaN
# 2025-03-07   0.865800   0.831101   0.700449   0.614125   0.614301   0.642682
# 2025-03-08   0.689748   0.687501   0.704046   0.690847   0.657569   0.620336
# 2025-03-09   0.724980   0.710634   0.664924   0.668784   0.703197   0.714941
# 2025-03-10   0.222907   0.207560   0.218010   0.231524   0.232545   0.236585
#
# hour        0.100000   0.116667   0.133333   0.150000   ...  23.833333  \
# date                                                    ...
# 2025-03-06        NaN        NaN        NaN        NaN  ...   0.564412
# 2025-03-07   0.651163   0.642807   0.630547   0.625207  ...   0.953117
# 2025-03-08   0.609117   0.641510   0.633631   0.483506  ...   0.732594
# 2025-03-09   0.716716   0.724327   0.720724   0.709794  ...   0.456068
# 2025-03-10   0.261414   0.289082   0.299038   0.295319  ...   0.729989
#
# hour        23.850000  23.866667  23.883333  23.900000  23.916667  23.933333  \
# date
# 2025-03-06   0.640855   0.758275   0.850200   0.890789   0.889279   0.847341
# 2025-03-07   0.966302   0.951707   0.891724   0.858797   0.890692   0.909769
# 2025-03-08   0.703666   0.690620   0.701983   0.722209   0.735367   0.739572
# 2025-03-09   0.413933   0.388911   0.369964   0.336207   0.295565   0.275891
# 2025-03-10   0.874596   0.924516   0.900368   0.897275   0.903425   0.882444
#
# hour        23.950000  23.966667  23.983333
# date
# 2025-03-06   0.786588   0.759989   0.804865
# 2025-03-07   0.886340   0.836823   0.756371
# 2025-03-08   0.725763   0.700367   0.701576
# 2025-03-09   0.277067   0.276096   0.255644
# 2025-03-10   0.865279   0.869847   0.867384
#
# [5 rows x 1440 columns]

# %%
plt.pcolormesh(pivot_table.columns, pivot_table.index, pivot_table.values)

# %%
data_filtered.resample("1min").mean()
# Out:
#                      NPM_filt  NAA_filt  NLK_filt  NLM_filt  NAU_filt
# 2025-03-06 17:00:00  0.770646  1.800785  0.634248  0.583853  0.000009
# 2025-03-06 17:01:00  0.757189  2.031668  0.713082  0.628566  0.000008
# 2025-03-06 17:02:00  0.765095  1.966668  0.787575  0.749128  0.000008
# 2025-03-06 17:03:00  0.781976  1.812400  0.822908  0.843021  0.000008
# 2025-03-06 17:04:00  0.785357  1.883562  0.812079  0.833989  0.000009
# ...                       ...       ...       ...       ...       ...
# 2025-03-20 04:55:00  2.883870  0.985906  0.709055  0.140709  0.000006
# 2025-03-20 04:56:00  2.983646  1.012426  0.729297  0.167471  0.000005
# 2025-03-20 04:57:00  3.028492  1.067462  0.715223  0.186263  0.000006
# 2025-03-20 04:58:00  3.138272  1.076227  0.717331  0.194224  0.000006
# 2025-03-20 04:59:00  3.400584  1.021463  0.815245  0.207501  0.000006
#
# [19440 rows x 5 columns]

# %% [markdown]
# ### IMPORTANT!
# The following parameters are required for loading and applying the FFT to each datafile.
# Since it is common to have around +25Gb of data, we divide the whole amount of datafiles into chunks to avoid RAM saturation. So, below there is the N_parts parammeter which is the number of chunks to iterate and process.
# Example if 30 Gb is the size of our data, using a N_parts=15 will give us a 2 Gb of data per processing at each iteration.
#
# Moreover, fft_npts_ovlp=is the number of points to use for each FFT during the overlapping
#
# About the method:
# - window: It is a single FFT that takes he first fft_npts points
# - overlap: It is a king of average FFT window taken alongside the signal.

# %%
a = ["naa", "frt", "eew"]
a.remove("frt")

# %%
a
# Out:
# ['naa', 'eew']

# %%
tio = time.time()
#fnames1 = fnames[1035:2070] # por partes
if method == "single":
    freq_w = np.arange(fft_npts)*sampling_freq/fft_npts
    id_0 = np.argmin(abs(freq_w-(f0-bw/2)))
    id_f = np.argmin(abs(freq_w-(f0+bw/2)))    
    freq_wtrim = freq_w[id_0:id_f]
    freq_wtrim = freq_w[id_0:id_f]
elif method == "overlap":
    freq_w= np.arange(fft_npts)*sampling_freq/fft_npts
    id_0 = np.argmin(abs(freq_w-(f0-bw/2)))
    id_f = np.argmin(abs(freq_w-(f0+bw/2)))
    freq_wtrim = freq_w[id_0:id_f]
nfiles = len(fnames)
time_arr = []
fftv =[]
COMP_FACT = 1
f0 = 24e3
bw=150

nbdata_sg = {}
nbdata = {key:[] for key in vlf_transmitters}

for k, f in enumerate(fnames):
    #print(f"File {f}\t {k+1} of {nfiles} processed \t -> {round((k+1)*100/nfiles, 2)} %",end="\r")
    print("File {:60s}\t {:7d} of {:7d} processed \t -> {:3.2f} %".format(f,k+1, nfiles, round((k+1)*100/nfiles, 2) ),end="\r")
    content = get_content(folder1+f)
    st = pd.read_csv(strio(content.decode()), comment="#", header=None, sep=",")
    st = st.values[:,0]+1j*st.values[:,1]  # signal IQ fmt
    # almaecnamos el tiempo en UTC : +5h
    time_arr.append(tools.get_date_from_fname(f) + datetime.timedelta(hours=5))
    #print("\napplying FFT {}".format(method))
    if method == "single":
        S = fft_pavnet.fft_window(st, wlen=fft_npts,fw=signal.windows.flattop)
        
    elif method == "overlap":
        S = fft_pavnet.fft_overlap(st, wlen=fft_npts,
                                   wfun=signal.windows.flattop, 
                                   povlp=povlp, ret_freq=False)

    else:
        
        break
    if SAVE_SPECTRUMS: fftv.append(S)
    
    # extraemos los datos de amplitud para cada transmisor (frecuencia)
    for ii, vlfname in  enumerate(vlf_transmitters):
        f0 = vlf_transmitters[vlfname]
        #print(f0)

        
        #amp_curve = track(fftv,freq_wtrim, ftarget=vlf_transmitters[vlfname], bw=200)
        amp_ = np.max(S[id_0:id_f],axis=0)
        nbdata[vlfname].append( amp_ )
       
        
    #axs[-1].set_xlim(left= datetime.datetime(2023,10,13,0,0), right= datetime.datetime(2023,10,13,1,))
    
print("\n>Completed \nin {:.2f} s".format(time.time()-tio))
#fftv = np.asarray(fftv)
# Out:
# File ANTAR_RAW_99994_28_12_2024_19_42_29__99994.txt.tar.gz       	  297923 of  297923 processed 	 -> 100.00 %
# >Completed
# in 2354.87 s

# %% [markdown]
# ## En caso de haber almacenado espectros
# ### Joining the data lists of Spectrums

# %%
fftv = np.asarray(fftv).T
timev = time_arr

# %%
fftv.shape, len(freq_wtrim), len(timev), len(freq_wtrim)
# Out:
# ((1803, 220), 1803, 220, 1803)

# %%
# In case of saving the FFTS
#pd.DataFrame(fftv,index=freq_wtrim, columns=timev).to_csv(folder1+"/fftv_040723-220723_fft{}pts_ovlp{}.csv".format(fft_npts_ovlp,povlp))

# %%
df_espectros = pd.DataFrame(fftv, index=freq_wtrim, columns=timev)

# %%
data = data[sorted(timev)] # ordenar en tiempo
df_espectros.head()
# Out:
#              2024-11-09 16:58:21  2024-11-09 16:58:30  2024-11-09 16:58:40  \
# 8996.582031             2.028373             2.037144             1.507041
# 9008.789062             1.952069             2.163907             1.833471
# 9020.996094             1.854219             2.092860             2.160410
# 9033.203125             1.862513             1.717930             2.345592
# 9045.410156             1.784675             1.355847             2.330002
#
#              2024-11-09 16:58:50  2024-11-09 16:59:00  2024-11-09 16:59:09  \
# 8996.582031             1.601416             1.978401             2.022812
# 9008.789062             1.290799             1.632206             1.678873
# 9020.996094             1.105131             1.336809             1.456168
# 9033.203125             0.955355             1.363305             1.437275
# 9045.410156             1.337572             1.311318             1.653672
#
#              2024-11-09 16:59:19  2024-11-09 16:59:29  2024-11-09 16:59:39  \
# 8996.582031             1.377550             1.814239             1.105047
# 9008.789062             1.022192             1.473919             0.988653
# 9020.996094             1.293815             1.334138             0.977324
# 9033.203125             1.942077             1.816927             1.169527
# 9045.410156             2.260685             1.801322             1.564669
#
#              2024-11-09 16:59:48  ...  2024-11-09 17:32:30  \
# 8996.582031             1.989865  ...             2.327347
# 9008.789062             1.578923  ...             2.390735
# 9020.996094             1.079589  ...             2.119087
# 9033.203125             1.021222  ...             1.904578
# 9045.410156             1.433540  ...             1.602324
#
#              2024-11-09 17:32:39  2024-11-09 17:32:49  2024-11-09 17:32:59  \
# 8996.582031             2.691971             2.421004             1.582548
# 9008.789062             2.534241             2.283969             1.548556
# 9020.996094             1.793242             1.716086             1.337541
# 9033.203125             1.407914             1.444569             1.222861
# 9045.410156             1.433092             1.416871             1.349612
#
#              2024-11-09 17:33:08  2024-11-09 17:33:18  2024-11-09 17:33:28  \
# 8996.582031             1.825166             1.962880             2.563164
# 9008.789062             1.856915             1.905922             2.580513
# 9020.996094             1.584593             1.550483             1.971872
# 9033.203125             1.282276             1.260307             1.847545
# 9045.410156             1.217847             1.030070             1.482519
#
#              2024-11-09 17:33:38  2024-11-09 17:33:47  2024-11-09 17:33:57
# 8996.582031             1.825195             2.018984             2.587132
# 9008.789062             1.828661             2.113063             2.793062
# 9020.996094             1.676593             1.779021             2.276890
# 9033.203125             1.925059             1.386446             1.829977
# 9045.410156             1.887258             1.002708             1.504267
#
# [5 rows x 220 columns]

# %%
data = data[sorted(timev)]

# %% [markdown]
# ## Para las señales de transmisoras: Amplitud
# ### Check the distribution of time

# %%
data = pd.DataFrame(nbdata, index=time_arr)

# %%
data.head()
# Out:
#                           NPM       NAA       NLK       NLM       NAU
# 2024-12-28 19:46:49  1.323540  2.789310  1.232200  2.375511  1.122843
# 2024-12-28 19:43:46  1.240974  2.243253  0.929637  2.477686  1.126240
# 2024-12-28 19:44:05  1.150930  2.566806  0.829360  2.296119  1.344157
# 2024-12-28 19:43:36  1.019458  2.231883  0.983248  2.442308  1.064832
# 2024-12-28 19:47:57  1.142034  2.701575  1.038949  2.141605  1.417858

# %%
data.sort_index(axis="index", inplace=True)
data.NAA.plot()
plt.xlim(datetime.datetime(2025,1,1), datetime.datetime(2025,1,2))
# Out:
# (20089.0, 20090.0)

# %%
vlf_transmitters #= {"24kTest": 24e3,"25ktest":25e3}
n = len(vlf_transmitters)
fig, axs = plt.subplots(n,1,figsize=(12,12),sharex=True)
#axs[0].set_title(str(fft_npts_ovlp) + " npts")
COMP_FACT = 1
f0 = 24e3
bw=150



sos = signal.butter(5, 0.04, 'lp', fs=1/10, output='sos')
time_arr = data.index
for ii, vlfname in  enumerate(vlf_transmitters):
    f0 = vlf_transmitters[vlfname]
    print(f0)
    
    amp_curve = data[vlfname]
    filtered = signal.sosfilt(sos, amp_curve)
    
    axs[ii].plot(time_arr, amp_curve,label=vlfname, linewidth=1, marker="s", markersize=2)
    axs[ii].plot(time_arr, filtered,label=vlfname+"-Filt", linewidth=2, color="red" )
    axs[ii].legend(fontsize=12, loc="upper left")
    axs[ii].grid()
    
    data[vlfname+"-FILT"] = filtered
    
#axs[-1].set_xlim(left= datetime.datetime(2023,10,13,0,0), right= datetime.datetime(2023,10,13,1,))
axs[-1].set_xlabel("TIME UT")
fig.autofmt_xdate()
#fig.suptitle("PIURA VLF 2024")
# Out:
# 21400.0
# 24000.0
# 24800.0
# 25200.0
# 40750.0

# %%
df = pd.DataFrame(nbdata,index=time_arr)
df
# Out:
#                           NPM       NAA       NLK       NLM       NAU  \
# 2024-12-28 17:29:09  1.323540  2.789310  1.232200  2.375511  1.122843
# 2024-12-28 17:29:18  1.240974  2.243253  0.929637  2.477686  1.126240
# 2024-12-28 17:29:28  1.150930  2.566806  0.829360  2.296119  1.344157
# 2024-12-28 17:29:38  1.019458  2.231883  0.983248  2.442308  1.064832
# 2024-12-28 17:29:47  1.142034  2.701575  1.038949  2.141605  1.417858
# ...                       ...       ...       ...       ...       ...
# 2025-02-02 06:33:58  2.872202  1.669691  0.576586  0.754752  0.258526
# 2025-02-02 06:34:08  2.654365  1.684894  0.683794  0.678977  0.232595
# 2025-02-02 06:34:18  2.099417  1.900309  0.644981  0.621103  0.261073
# 2025-02-02 06:34:27  1.505931  2.817113  0.769943  2.207965  1.071065
# 2025-02-02 06:34:37  1.366785  3.081265  1.156460  2.366055  1.269548
#
#                          NPM-FILT      NAA-FILT      NLK-FILT      NLM-FILT  \
# 2024-12-28 17:29:09  8.603422e-13  1.813138e-12  8.009686e-13  1.544156e-12
# 2024-12-28 17:29:18  1.732243e-11  3.626452e-11  1.598028e-11  3.125334e-11
# 2024-12-28 17:29:28  1.740688e-10  3.622924e-10  1.590823e-10  3.156954e-10
# 2024-12-28 17:29:38  1.169216e-09  2.421527e-09  1.058613e-09  2.131658e-09
# 2024-12-28 17:29:47  5.931899e-09  1.223648e-08  5.322481e-09  1.087219e-08
# ...                           ...           ...           ...           ...
# 2025-02-02 06:33:58  1.856479e+00  2.132861e+00  8.144665e-01  1.494910e+00
# 2025-02-02 06:34:08  1.867203e+00  2.128370e+00  8.120860e-01  1.484696e+00
# 2025-02-02 06:34:18  1.877378e+00  2.123282e+00  8.093082e-01  1.474984e+00
# 2025-02-02 06:34:27  1.887104e+00  2.117547e+00  8.061504e-01  1.465653e+00
# 2025-02-02 06:34:37  1.896494e+00  2.111120e+00  8.026329e-01  1.456572e+00
#
#                          NAU-FILT
# 2024-12-28 17:29:09  7.298830e-13
# 2024-12-28 17:29:18  1.474346e-11
# 2024-12-28 17:29:28  1.488291e-10
# 2024-12-28 17:29:38  1.005398e-09
# 2024-12-28 17:29:47  5.134883e-09
# ...                           ...
# 2025-02-02 06:33:58  7.783085e-01
# 2025-02-02 06:34:08  7.733366e-01
# 2025-02-02 06:34:18  7.687843e-01
# 2025-02-02 06:34:27  7.645460e-01
# 2025-02-02 06:34:37  7.605097e-01
#
# [297923 rows x 10 columns]

# %%
tx = "NAA"
ti = datetime.datetime(2025,1,1)
tf = datetime.datetime(2025,1,2)
df.loc[ti:tf , tx].plot(color="gray", marker=".", 
                                                                             lw=0, alpha=0.25, label="Raw")
                                                                                                           
df.loc[datetime.datetime(2025,1,1):datetime.datetime(2025,1,2) , f"{tx}-FILT"].plot(color="firebrick", lw=3, 
                                                                                  label="Filtered")
plt.legend()
plt.ylabel(" Linear Amp. ")
plt.xlabel("Time (UTC)")
# Out:
# Text(0.5, 0, 'Time (UTC)')

# %%
df_db = df.apply(lambda x: 20*np.log10(x))
# Out:
# /home/aldo/.local/lib/python3.10/site-packages/pandas/core/arraylike.py:399: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
tx = "NAA"
ti = datetime.datetime(2025,1,1)
tf = datetime.datetime(2025,1,2)
df_db.loc[ti:tf , tx].plot(color="gray", marker=".", 
                                                                             lw=0, alpha=0.25, label="Raw")
                                                                                                           
df_db.loc[datetime.datetime(2025,1,1):datetime.datetime(2025,1,2) , f"{tx}-FILT"].plot(color="firebrick", lw=3, 
                                                                                  label="Filtered")
plt.legend()
plt.ylabel(" Amp. dB ")
plt.xlabel("Time (UTC)")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 tx = "NAA"
# ----> 2 ti = datetime.datetime(2025,1,1)
#       3 tf = datetime.datetime(2025,1,2)
#       4 df_db.loc[ti:tf , tx].plot(color="gray", marker=".",
#       5                                                                              lw=0, alpha=0.25, label="Raw")
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# ## Guardar la data  de transmisoras(narrowband)

# %%
# alistamos la data en un dataframe
outdata = data


outdata.tail()
# Out:
#                           NPM       NAA       NLK       NLM       NAU  \
# 2025-02-02 06:33:58  7.657877  1.862685  2.453454  0.096239  0.317613
# 2025-02-02 06:34:08  6.289041  2.405478  1.639732  0.162761  0.279381
# 2025-02-02 06:34:18  7.246017  1.606702  2.472915  0.159731  0.299608
# 2025-02-02 06:34:27  7.167607  1.801642  2.553332  0.081922  0.233904
# 2025-02-02 06:34:37  6.365127  2.062064  1.905122  0.107006  0.241273
#
#                      NPM-FILT  NAA-FILT  NLK-FILT  NLM-FILT  NAU-FILT
# 2025-02-02 06:33:58  6.851042  1.998417  2.555558  0.106086  0.303429
# 2025-02-02 06:34:08  7.302062  2.167174  2.252748  0.149805  0.295756
# 2025-02-02 06:34:18  6.727026  2.037162  1.774336  0.140598  0.294468
# 2025-02-02 06:34:27  6.831611  1.740104  2.501240  0.147767  0.267806
# 2025-02-02 06:34:37  7.399661  1.753121  2.563404  0.085183  0.238273

# %%
data.to_csv(f"{resfolder}/PIU_AMPCURVES_{data.index[0]}-to-{data.index[-1]}.csv")
print("GUARDADO")
# Out:
# GUARDADO

# %% [markdown]
# ## Solar X rays

# %%
import sxrf_download

# %%
OUTPUT_PATH = None #f"{resfolder}/xrayflux"
d_i = "2024-12-28 00:00"#datetime.datetime(2023, 11,2) #1st day
d_f = "2025-02-01 00:00"#datetime.datetime(2023, 11,15)  #last day


#dates = [d_i+datetime.timedelta(days=int(d)) for d in range(nd.days+1)]

# %%
# !mkdir -p $OUTPUT_PATH

# %%
# lista de dias de lso que queremos datos (solar x-ray flux )
periodo = [datetime.datetime(2024,12,27)+datetime.timedelta(days=k) for k in range(45)]
xr = sxrf_download.download_xrayfluxdata(periodo)
# Out:
# URL: https://climaespacial.conida.gob.pe/GOES/DatosClimaEspacial/AnalizarDatoXrays_Recolectar.php?index=6&fecha={}
# Downloading 2024-12-27... Downloading 2024-12-28... Downloading 2024-12-29... Downloading 2024-12-30... Downloading 2024-12-31... Downloading 2025-01-01... Downloading 2025-01-02... Downloading 2025-01-03... Downloading 2025-01-04... Downloading 2025-01-05... Downloading 2025-01-06... Downloading 2025-01-07... Downloading 2025-01-08... Downloading 2025-01-09... Downloading 2025-01-10... Downloading 2025-01-11... Downloading 2025-01-12... Downloading 2025-01-13... Downloading 2025-01-14... Downloading 2025-01-15... Downloading 2025-01-16... Downloading 2025-01-17... Downloading 2025-01-18... Downloading 2025-01-19... Downloading 2025-01-20... Downloading 2025-01-21... Downloading 2025-01-22... Downloading 2025-01-23... Downloading 2025-01-24... Downloading 2025-01-25... Downloading 2025-01-26... Downloading 2025-01-27... Downloading 2025-01-28... Downloading 2025-01-29... Downloading 2025-01-30... Downloading 2025-01-31... Downloading 2025-02-01... Downloading 2025-02-02... Downloading 2025-02-03... Downloading 2025-02-04... Downloading 2025-02-05... Downloading 2025-02-06...
# /home/aldo/jupyter/notebooks/code/sxrf_download.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_xr = pd.concat([df_xr, dfcsv])
# Downloading 2025-02-07...
# /home/aldo/jupyter/notebooks/code/sxrf_download.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_xr = pd.concat([df_xr, dfcsv])
# Downloading 2025-02-08...
# /home/aldo/jupyter/notebooks/code/sxrf_download.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_xr = pd.concat([df_xr, dfcsv])
# Downloading 2025-02-09...
# Completed.
# /home/aldo/jupyter/notebooks/code/sxrf_download.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_xr = pd.concat([df_xr, dfcsv])

# %%
xr.set_index("DateTime", inplace=True)

# %%
xr.head()
# Out:
#                      GOES-18 long  GOES-18 short  GOES-16 long  GOES-16 short  \
# DateTime
# 2024-12-27 00:00:00      0.000004   1.260000e-07      0.000004   1.400000e-07
# 2024-12-27 00:01:00      0.000003   8.570000e-08           NaN            NaN
# 2024-12-27 00:02:00      0.000003   6.110000e-08           NaN            NaN
# 2024-12-27 00:03:00      0.000003   5.600000e-08           NaN            NaN
# 2024-12-27 00:04:00      0.000003   7.520000e-08      0.000003   9.270000e-08
#
#                     GOES-17 long GOES-17 short
# DateTime
# 2024-12-27 00:00:00          NaN           NaN
# 2024-12-27 00:01:00          NaN           NaN
# 2024-12-27 00:02:00          NaN           NaN
# 2024-12-27 00:03:00          NaN           NaN
# 2024-12-27 00:04:00          NaN           NaN

# %%
tx = "NAA"
ti = datetime.datetime(2025,1,28)
tf = datetime.datetime(2025,1,30)

fig, ax = plt.subplots()
plt.plot(df_db.loc[ti:tf , tx],color="gray", marker=".", 
                            lw=0, alpha=0.25, label="Raw",)

plt.plot(df_db.loc[ti:tf , f"{tx}-FILT"], color="firebrick", lw=3, 
                                      label="Filtered",)
plt.legend()
plt.ylabel(" Amp. dB ")
plt.xlabel("Time (UTC)")

# twin x plot for SXRF 
ax2 = ax.twinx()
ax2.plot(xr.loc[ti:tf, "GOES-18 long"],color="slateblue", lw=2)
ax2.set_yscale("log")
ax2.set_ylim(1e-6, 1e-3)
fig.autofmt_xdate()
plt.title(f"{tx}-PIU")
# Out:
# Text(0.5, 1.0, 'NAA-PIU')

# %%
tx = "NAA"
ti = datetime.datetime(2025,1,28,18)
tf = datetime.datetime(2025,1,28,23,59 )

fig, ax = plt.subplots()
plt.plot(df_db.loc[ti:tf , tx],color="gray", marker=".", 
                            lw=0, alpha=0.25, label="Raw",)

plt.plot(df_db.loc[ti:tf , f"{tx}-FILT"], color="firebrick", lw=3, 
                                      label="Filtered",)
plt.legend()
plt.ylabel(" Amp. dB ")
plt.xlabel("Time (UTC)")

# twin x plot for SXRF 
ax2 = ax.twinx()
ax2.plot(xr.loc[ti:tf, "GOES-18 long"],color="slateblue", lw=2)
ax2.set_yscale("log")
ax2.set_ylim(1e-6, 1e-3)
fig.autofmt_xdate()
plt.title(f"{tx}-PIU")
# Out:
# Text(0.5, 1.0, 'NAA-PIU')

# %%
df_db.index += datetime.timedelta(hours=5)
df.index += datetime.timedelta(hours=5)

# %%
ax = plt.gca()
df_db.loc[datetime.datetime(2024,12,31):datetime.datetime(2025,1,1), "NAA-FILT"].plot()
ax2 = ax.twinx()
ax2.plot(xr.loc[datetime.datetime(2024,12,31):datetime.datetime(2025,1,1), "GOES-18 long"])

# %%
df_db.astype(
# Out:
# NPM         float64
# NAA         float64
# NLK         float64
# NLM         float64
# NAU         float64
# NPM-FILT    float64
# NAA-FILT    float64
# NLK-FILT    float64
# NLM-FILT    float64
# NAU-FILT    float64
# dtype: object
