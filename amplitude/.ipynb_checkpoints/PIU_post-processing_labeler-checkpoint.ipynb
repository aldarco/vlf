# %% [markdown]
#  SOLAR FLARES DETECTED
# ## Analysis

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.signal as signal
import datetime as dt
import os
from matplotlib.dates import DateFormatter
from matplotlib.ticker import MultipleLocator, AutoMinorLocator

# %%
plt.rcParams["font.size"]=14
plt.rcParams["figure.figsize"]=(8,6)

# %%
! ls  /data/PAVNET/2024/PLO_16112023-26112023/
# Out:
# ls: no se puede acceder a '/data/PAVNET/2024/PLO_16112023-26112023/': No existe el archivo o el directorio

# %%
datapath = "/data/PAVNET/2024/PLO_16112023-26112023/"
#dnoct21 = "OCT21_4096_flattop_NAA.txt"
#dnjul22 = "JUL22_4096_flattop_NAA.txt"

dndata_path = datapath+'AMPCURVES_2023-11-15 18:01:33-2023-11-29 15:45:15_FFT4096pts_ovlp25.csv'

xraysdata = datapath + "xrayflux/"
#savnetdata = datapath + "PLO_250822-010922/SAVNET/PLO-26-07-2022.txt"

# %%
dndata_path
# Out:
# '/data/PAVNET/2024/PLO_16112023-26112023/MPCURVES_2023-11-15 18:01:33-2023-11-29 15:45:15_FFT4096pts_ovlp25.csv'

# %%
dateparser = lambda x: dt.datetime.strptime(x, "%Y-%m-%d %H:%M:%S")
def todatetime(x):
    ts = str(pd.Timestamp(x))
    ts = dt.datetime.strptime(ts, "%Y-%m-%d %H:%M:%S")
    return ts
dndata = pd.read_csv(dndata_path, header=0, parse_dates=[0], date_parser=dateparser)
ccc = dndata.columns.values
ccc[0] = "DateTime"
dndata.columns = ccc
del ccc
#dndata.head(5)
timevdn = np.array(list(map(todatetime,dndata['DateTime'].values)))
#amp_jul = data_jul[1]
# Out:
# /tmp/ipykernel_8512/2680885086.py:6: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   dndata = pd.read_csv(dndata_path, header=0, parse_dates=[0], date_parser=dateparser)

# %%
dndata["DateTime"].values[0], dndata["DateTime"].values[-1]
# Out:
# (numpy.datetime64('2023-11-15T18:01:33.000000000'),
#  numpy.datetime64('2023-11-29T15:45:15.000000000'))

# %%
dndata.head(5)
# Out:
#              DateTime       NWC       NPM       JJI       NAA       NLK  \
# 0 2023-11-15 18:01:33  0.768971  0.597794  0.695329  1.704087  0.692887
# 1 2023-11-15 18:02:02  0.706458  0.310205  0.691598  1.837156  0.730710
# 2 2023-11-15 18:02:21  0.945436  0.520285  1.043231  2.308695  0.903679
# 3 2023-11-15 18:03:58  0.883772  0.568776  0.959721  2.350275  1.227249
# 4 2023-11-15 18:05:06  0.871157  0.610290  0.714167  2.193448  1.273115
#
#         NLM
# 0  0.362155
# 1  0.503650
# 2  0.552650
# 3  0.751332
# 4  0.491510

# %%
#refmin = np.mean(dndata.min(numeric_only=True))
refmin=np.mean(dndata.mean(numeric_only=True))

# %%
#dndata_sg = pd.DataFrame()
wlen = 11
order = 1

dndatadb = pd.DataFrame()
dndatadb_sg = pd.DataFrame()
for tx in dndata.columns[1:]:
    dndatadb[tx] = 20*np.log10(dndata[tx].values/refmin)
    dndatadb_sg[tx] = signal.savgol_filter(dndatadb[tx], wlen, order)

# %%
dndatadb_sg
# Out:
#            NWC       NPM       JJI       NAA       NLK        NLM
# 0    -4.381241 -8.031389 -4.110537  4.218999 -3.137735  -7.703233
# 1    -3.926181 -7.339812 -3.999550  4.255348 -3.015156  -7.342092
# 2    -3.471121 -6.648236 -3.888562  4.291696 -2.892578  -6.980950
# 3    -3.016061 -5.956659 -3.777575  4.328044 -2.769999  -6.619809
# 4    -2.561001 -5.265083 -3.666588  4.364393 -2.647421  -6.258667
# ...        ...       ...       ...       ...       ...        ...
# 9970 -4.073294 -0.300211 -4.022381  4.993248 -6.120110  -8.241776
# 9971 -4.471716 -0.846365 -4.682564  4.990610 -6.640785  -9.183860
# 9972 -4.870138 -1.392519 -5.342747  4.987972 -7.161461 -10.125944
# 9973 -5.268560 -1.938672 -6.002931  4.985335 -7.682136 -11.068028
# 9974 -5.666982 -2.484826 -6.663114  4.982697 -8.202812 -12.010112
#
# [9975 rows x 6 columns]

# %%
fig, axs = plt.subplots(nrows=len(dndata.columns[1:]), ncols=1, sharex=True, 
                        sharey=True,figsize=(12,10))
di = dt.datetime(2024,11 ,1)
df = dt.datetime(2024,11,30, 18)

for ii,tx in enumerate(dndata.columns[1:]):
    axs[ii].plot(timevdn, dndatadb[tx], linewidth=0,marker='o', color="lightgray",
                 alpha=0.4, markersize=2)
    axs[ii].plot(timevdn, dndatadb_sg[tx],  color="darkblue", )
    axs[ii].text(0.04,0.035,tx, transform=axs[ii].transAxes, color="dimgray")
    axs[ii].grid(axis="x", linestyle=":")
#plt.xlim(di,df)
plt.ylim(bottom=-30, top=30)
fig.autofmt_xdate()
fig.text(-0.1,0.5, "Amplitud (dB)", fontsize=16,transform=axs[3].transAxes, rotation="vertical")
fig.text(0.4,-1., "Año-Mes-Día (UT)", fontsize=16
         ,transform=axs[-1].transAxes)
plt.tight_layout()
plt.subplots_adjust(hspace=0)

# %%
plt.rcParams["font.size"]=18

# %%
di = dt.datetime(2023,11, 23)
df = dt.datetime(2023, 11, 24)

fig = plt.figure(figsize=(20,6))
plt.plot(timevdn[(di<timevdn) & (timevdn<df)], dndatadb['NAA'].iloc[(di<timevdn) & (timevdn<df)], marker="o",color="blue",alpha=1, label="medido")
#plt.plot(timevdn[(di<timevdn) & (timevdn<df)], dndatadb_sg['NAA'].iloc[(di<timevdn) & (timevdn<df)],  color="black", label='suavizado')
#plt.xlim(dt.datetime(2023, 3,31,0), dt.datetime(2023, 4,12))
plt.xlabel("Tiempo")
plt.ylabel("Amplitud (dB)")
plt.legend()
plt.title(di)
#plt.ylim(-20,0)
# Out:
# Text(0.5, 1.0, '2023-11-23 00:00:00')

# %%
# drop wrond dates
#vlfdata = dndatadb_sg[(dt.datetime(2022, 8,26,0)<dndatadb_sg["DateTime"]) & (dndatadb_sg["DateTime"]<dt.datetime(2022, 9,2,0))]

dndatadb_sg["DateTime"] = dndata["DateTime"]#["NAA"])

# %%
vlfdata = dndatadb_sg

# %%
tt = vlfdata["DateTime"].dt.date

# %%
#vlfdata.groupby(vlfdata["DateTime"].dt.date).count()
ttcounts = tt.groupby(tt).count()

# %%
ttcounts.index
# Out:
# Index([2023-11-15, 2023-11-16, 2023-11-17, 2023-11-18, 2023-11-19, 2023-11-20,
#        2023-11-21, 2023-11-22, 2023-11-23, 2023-11-24, 2023-11-25, 2023-11-26,
#        2023-11-27, 2023-11-28, 2023-11-29],
#       dtype='object', name='DateTime')

# %%
fig = plt.figure()
#plt.hist(tt, rwidth=0.5, align='mid', bins=12)
plt.bar(ttcounts.index,ttcounts.values)
fig.autofmt_xdate()
plt.title("VLF datalength / date")
# Out:
# Text(0.5, 1.0, 'VLF datalength / date')

# %%
sum(ttcounts.values)
# Out:
# 9975

# %% [markdown]
# # Loading XrAYS

# %%
dd = ! ls $xraysdata
dd
# Out:
# ['XRF_15112023.csv',
#  'XRF_16112023.csv',
#  'XRF_17112023.csv',
#  'XRF_18112023.csv',
#  'XRF_19112023.csv',
#  'XRF_20112023.csv',
#  'XRF_21112023.csv',
#  'XRF_22112023.csv',
#  'XRF_23112023.csv',
#  'XRF_24112023.csv',
#  'XRF_25112023.csv',
#  'XRF_26112023.csv',
#  'XRF_27112023.csv',
#  'XRF_28112023.csv',
#  'XRF_29112023.csv',
#  'XRF_30112023.csv']

# %%
#dd.append(dd[0])
#del(dd[0])
#dd

# %%
xrdata = pd.DataFrame()
#xrdata = pd.read_csv(xraysdata+dd[0], usecols=[0,3])
t_aux = []
f_aux = []

for ii, xx in enumerate(dd):
    print("loading: ",xx)
    x = pd.read_csv(xraysdata+'/'+dd[ii],  parse_dates=[0]) #.values
    xrdata = pd.concat([xrdata,x])
    t_aux += list(x["DateTime"])
    #f_aux += list(x[:,1])
xrdata["DateTime"] = pd.to_datetime(xrdata["DateTime"])
xrtime = np.asarray(t_aux)
xrayflux = np.asarray(f_aux)
# Out:
# loading:  XRF_15112023.csv
# loading:  XRF_16112023.csv
# loading:  XRF_17112023.csv
# loading:  XRF_18112023.csv
# loading:  XRF_19112023.csv
# loading:  XRF_20112023.csv
# loading:  XRF_21112023.csv
# loading:  XRF_22112023.csv
# loading:  XRF_23112023.csv
# loading:  XRF_24112023.csv
# loading:  XRF_25112023.csv
# loading:  XRF_26112023.csv
# loading:  XRF_27112023.csv
# loading:  XRF_28112023.csv
# loading:  XRF_29112023.csv
# loading:  XRF_30112023.csv

# %%
xrdata
# Out:
#                 DateTime  GOES-16_short  GOES-16_long
# 0    2023-11-15 00:00:00   5.108240e-08      0.000002
# 1    2023-11-15 00:01:00   4.863634e-08      0.000002
# 2    2023-11-15 00:02:00   4.844537e-08      0.000002
# 3    2023-11-15 00:03:00   4.875007e-08      0.000001
# 4    2023-11-15 00:04:00   4.658941e-08      0.000001
# ...                  ...            ...           ...
# 1435 2023-11-30 23:55:00   4.625021e-08      0.000002
# 1436 2023-11-30 23:56:00   4.547473e-08      0.000002
# 1437 2023-11-30 23:57:00   4.451385e-08      0.000002
# 1438 2023-11-30 23:58:00   4.178248e-08      0.000002
# 1439 2023-11-30 23:59:00   4.150197e-08      0.000002
#
# [23040 rows x 3 columns]

# %%
xrdata = xrdata.sort_values(by=["DateTime"])
#xrdata = xrdata[(dt.datetime(2023, 1,26)<xrdata["DateTime"]) & (xrdata["DateTime"]<dt.datetime(2023, 2,7))]
plt.plot(xrdata["DateTime"].values, 's')

# %% [markdown]
# # loaing Savnet data

# %%
fnames = os.listdir(datapath+'/SAVNET_2608-0209')
fnames
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 fnames = os.listdir(datapath+'/SAVNET_2608-0209')
#       2 fnames
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/PAVNET/2024/PLO_PAVNET29112023//SAVNET_2608-0209'

# %%
datapath
# Out:
# '/data/Datos_PLO/PLO/2023/PLO_220623-020723/'

# %%
fdates = []
tvsavnet, ampsavnet = [], []
datasavnet = pd.DataFrame()
for fn in fnames:
    print(fn)
    x = fn.split(".")[0].split('-')[1:]
    t_ = dt.datetime(int(x[-1]),int(x[-2]), int(x[-3]))
    x = pd.read_csv(datapath+'/SAVNET_2608-0209/'+fn, delimiter='\t', skiprows=4)#np.loadtxt(datapath+'/SAVNET_2608-0209/'+fn, delimiter='\t', skiprows=5)
    #ts, amp = x[:, 0], x[:, 1] 
    datasavnet = datasavnet.append(x, ignore_index=True)
    tvsavnet += [t_ + dt.timedelta(seconds=ss) for ss in x[x.columns[0]]]
    #ampsavnet += list(x[:,1])
tvsavnet = np.asarray(tvsavnet)
datasavnet["DateTime"] = tvsavnet

#ampsavnet = np.asarray(ampsavnet)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-57b29954d169> in <module>
#       2 tvsavnet, ampsavnet = [], []
#       3 datasavnet = pd.DataFrame()
# ----> 4 for fn in fnames:
#       5     print(fn)
#       6     x = fn.split(".")[0].split('-')[1:]
#
# NameError: name 'fnames' is not defined

# %%
datasavnet
# Out:
#          Range=  60.00 dB            DateTime
# 0           0.0     20.31 2022-08-27 00:00:00
# 1           1.0     20.16 2022-08-27 00:00:01
# 2           2.0     20.42 2022-08-27 00:00:02
# 3           3.0     20.48 2022-08-27 00:00:03
# 4           4.0     19.95 2022-08-27 00:00:04
# ...         ...       ...                 ...
# 691195  86395.0     19.54 2022-08-29 23:59:55
# 691196  86396.0     19.82 2022-08-29 23:59:56
# 691197  86397.0     19.68 2022-08-29 23:59:57
# 691198  86398.0     19.79 2022-08-29 23:59:58
# 691199  86399.0     20.11 2022-08-29 23:59:59
#
# [691200 rows x 3 columns]

# %%
datasavnet.sort_values("DateTime", inplace=True)
datasavnet
# Out:
#          Range=  60.00 dB            DateTime
# 518400      0.0     19.60 2022-08-26 00:00:00
# 518401      1.0     19.60 2022-08-26 00:00:01
# 518402      2.0     19.65 2022-08-26 00:00:02
# 518403      3.0     19.55 2022-08-26 00:00:03
# 518404      4.0     19.55 2022-08-26 00:00:04
# ...         ...       ...                 ...
# 345595  86395.0     19.43 2022-09-02 23:59:55
# 345596  86396.0     19.37 2022-09-02 23:59:56
# 345597  86397.0     18.89 2022-09-02 23:59:57
# 345598  86398.0     19.23 2022-09-02 23:59:58
# 345599  86399.0     19.30 2022-09-02 23:59:59
#
# [691200 rows x 3 columns]

# %%
# Out:
# numpy.datetime64('2022-09-01')

# %% [markdown]
# # Solar Flares

# %% [markdown]
# ### M & C Type Solar Flares

# %%
# finding peaks -> explosions
c = 1e6
threshold_C = [1]
peaks_c, x_c = signal.find_peaks(xrdata["GOES-16_long"].values*c,rel_height=10,distance=5, prominence=2)


fig = plt.figure(figsize=(12, 6))


plt.plot(xrdata['DateTime'], xrdata["GOES-16_long"]*c)
plt.scatter(xrdata['DateTime'].iloc[peaks_c], xrdata["GOES-16_long"].iloc[peaks_c]*c, marker='s', c="red",label="Explosion detectada")
fig.autofmt_xdate()

# C class flare region
plt.axhspan(1e-7*c,1e-6*c, color="yellow", alpha=0.1, label="Tipo B")
plt.axhspan(1e-6*c,1e-5*c, color="yellow", alpha=0.3, label="Tipo C")
plt.axhspan(1e-5*c,1e-4*c, color="orange", alpha=0.3, label="Tipo M")
plt.axhspan(1e-4*c, 1e-3*c , color="red", alpha=0.3, label="Tipo X")
#plt.axhspan(1e-5,1e-5, color="yellow", alpha=0.3)
plt.legend(framealpha=1,facecolor='whitesmoke')
plt.ylabel("Flujo de Rayos X ($\mu Wm^{-2}$)")
plt.xlabel("Tiempo (Año-Mes-Día)")
plt.ylim(0.1,500)
plt.yscale("log")
#plt.xlim(dt.datetime(2022,8,30,9), dt.datetime(2022,8,31))

# %%
fig.savefig(datapath+"/X-Ray_fux_andflares.png", dpi=300)

# %%
#fig.savefig(datapath+'/X-RAY_flux_2_MtypeMarked.png', dpi=300)

# %%
flaresdf = xrdata.iloc[peaks_c]

# %%
#flaresdf = flaresdf.drop(index=[1600, 5304,5345, 5371, 2974, 3348,5216])
#flaresdf

# %% [markdown]
# ### Agregando manualmente algunas explosiones

# %%
#x = pd.DataFrame(columns=["Tiempo Universal", "GOES-17_long"])
#x.index = 2208
#x["Tiempo Universal"]= pd.to_datetime(["2022-08-27 12:48:00", "2022-08-27 13:13:00", "2022-08-28 01:34:00", "2022-08-29 21:54:00", "2022-08-30 11:43:00" ])
#x["GOES-17_long"] = [0.000009, 0.000010, 0.000015, 0.000006, 0.000003]
#x.index = [2208,2233, 2974, 5634, 6463]

# %%
#flaresdf = pd.concat([flaresdf, x])

# %%
flaresdf.sort_values("DateTime", inplace =True)
flaresdf
# Out:
# /tmp/ipykernel_11793/1651436307.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flaresdf.sort_values("DateTime", inplace =True)
#                 DateTime  GOES-16_short  GOES-16_long
# 241  2023-11-15 04:01:00   9.087609e-07      0.000008
# 732  2023-11-15 12:12:00   9.595423e-07      0.000008
# 1222 2023-11-16 20:22:00   4.784055e-07      0.000005
# 342  2023-11-18 05:42:00   3.243163e-06      0.000013
# 643  2023-11-18 10:43:00   4.048076e-07      0.000004
# 1353 2023-11-18 22:33:00   9.904322e-07      0.000011
# 514  2023-11-19 08:34:00   8.997195e-07      0.000008
# 1332 2023-11-19 22:12:00   1.506653e-07      0.000004
# 426  2023-11-20 07:06:00   3.729320e-07      0.000004
# 453  2023-11-20 07:33:00   3.208299e-07      0.000004
# 543  2023-11-20 09:03:00   2.896000e-06      0.000013
# 614  2023-11-20 10:14:00   4.041524e-07      0.000005
# 751  2023-11-20 12:31:00   1.375066e-06      0.000008
# 78   2023-11-21 01:18:00   4.478588e-07      0.000006
# 225  2023-11-21 03:45:00   1.035691e-06      0.000007
# 832  2023-11-21 13:52:00   8.850070e-07      0.000008
# 1420 2023-11-21 23:40:00   2.500968e-07      0.000004
# 71   2023-11-22 01:11:00   8.239099e-07      0.000008
# 388  2023-11-22 06:28:00   9.764193e-07      0.000009
# 1005 2023-11-22 16:45:00   2.324548e-07      0.000005
# 1226 2023-11-22 20:26:00   4.708728e-07      0.000006
# 3    2023-11-23 00:03:00   4.029737e-07      0.000006
# 218  2023-11-23 03:38:00   1.148681e-06      0.000015
# 344  2023-11-23 05:44:00   4.711173e-07      0.000008
# 434  2023-11-23 07:14:00   3.215306e-07      0.000007
# 795  2023-11-23 13:15:00   6.380895e-07      0.000006
# 877  2023-11-23 14:37:00   1.252900e-06      0.000011
# 938  2023-11-23 15:38:00   4.005479e-07      0.000006
# 1161 2023-11-23 19:21:00   1.488633e-07      0.000004
# 1239 2023-11-23 20:39:00   1.332536e-06      0.000009
# 1265 2023-11-23 21:05:00   3.506331e-07      0.000004
# 573  2023-11-24 09:33:00   1.172922e-06      0.000011
# 642  2023-11-24 10:42:00   8.711240e-07      0.000008
# 1339 2023-11-24 22:19:00   4.704575e-07      0.000006
# 879  2023-11-25 14:39:00   1.803988e-07      0.000004
# 464  2023-11-26 07:44:00   2.362728e-07      0.000004
# 491  2023-11-27 08:11:00   1.611074e-07      0.000003
# 1132 2023-11-27 18:52:00   5.546937e-07      0.000007
# 1419 2023-11-27 23:39:00   2.868288e-07      0.000006
# 1190 2023-11-28 19:50:00   2.055558e-05      0.000099
# 1411 2023-11-28 23:31:00   6.212568e-07      0.000008
# 483  2023-11-29 08:03:00   6.273109e-07      0.000006
# 875  2023-11-29 14:35:00   2.667075e-07      0.000004

# %%
#flaresdf.drop(index=[2974, 4538, 5860], inplace=True)

# %%
flares_t = flaresdf['DateTime']
flares_t
# Out:
# 241    2023-11-15 04:01:00
# 732    2023-11-15 12:12:00
# 1222   2023-11-16 20:22:00
# 342    2023-11-18 05:42:00
# 643    2023-11-18 10:43:00
# 1353   2023-11-18 22:33:00
# 514    2023-11-19 08:34:00
# 1332   2023-11-19 22:12:00
# 426    2023-11-20 07:06:00
# 453    2023-11-20 07:33:00
# 543    2023-11-20 09:03:00
# 614    2023-11-20 10:14:00
# 751    2023-11-20 12:31:00
# 78     2023-11-21 01:18:00
# 225    2023-11-21 03:45:00
# 832    2023-11-21 13:52:00
# 1420   2023-11-21 23:40:00
# 71     2023-11-22 01:11:00
# 388    2023-11-22 06:28:00
# 1005   2023-11-22 16:45:00
# 1226   2023-11-22 20:26:00
# 3      2023-11-23 00:03:00
# 218    2023-11-23 03:38:00
# 344    2023-11-23 05:44:00
# 434    2023-11-23 07:14:00
# 795    2023-11-23 13:15:00
# 877    2023-11-23 14:37:00
# 938    2023-11-23 15:38:00
# 1161   2023-11-23 19:21:00
# 1239   2023-11-23 20:39:00
# 1265   2023-11-23 21:05:00
# 573    2023-11-24 09:33:00
# 642    2023-11-24 10:42:00
# 1339   2023-11-24 22:19:00
# 879    2023-11-25 14:39:00
# 464    2023-11-26 07:44:00
# 491    2023-11-27 08:11:00
# 1132   2023-11-27 18:52:00
# 1419   2023-11-27 23:39:00
# 1190   2023-11-28 19:50:00
# 1411   2023-11-28 23:31:00
# 483    2023-11-29 08:03:00
# 875    2023-11-29 14:35:00
# Name: DateTime, dtype: datetime64[ns]

# %% [markdown]
# # Flares through some VLF

# %%
fig = plt.figure(figsize=(8,6))

tx="NAA"
plt.subplot(211)
delta = dt.timedelta(minutes=30)
ax = plt.gca()
plt.plot(vlfdata["DateTime"], vlfdata[tx] , label=tx)
ax2 = ax.twinx()
ax2.plot(xrdata.iloc[:,0], xrdata.iloc[:,2] , label="XRF", color="red")
for tf in flares_t:
    ax.axvspan(tf-delta,tf+delta, color='orange', alpha=0.3)
ax2.set_yscale("log")
ax2.set_ylim(1e-7, 1e-4)
ax.set_ylim(bottom=-20)
ax.legend()
#ax.vlines(x=dt.datetime(2023,11,10,), ymin=-20,ymax=20,  ls="--", color="green")
ax.set_xlim(dt.datetime(2023,11,17), dt.datetime(2023,10,18))

tx = "NLK"
plt.subplot(212, sharex=ax)
delta = dt.timedelta(minutes=30)
ax = plt.gca()
plt.plot(vlfdata["DateTime"], vlfdata[tx] , label=tx)
ax2 = ax.twinx()
ax2.plot(xrdata.iloc[:,0], xrdata.iloc[:,2] , label=tx, color="red")
for tf in flares_t:
    ax.axvspan(tf-delta,tf+delta, color='orange', alpha=0.3)
    print(tf)
ax2.set_yscale("log")
ax2.set_ylim(1e-7, 1e-4)
ax.set_ylim(bottom=-20)
ax.legend()
ax.set_xlim(dt.datetime(2023,11,17), dt.datetime(2023,11,18))
#ax.vlines(x=dt.datetime(2023,10,14,18,40), ymin=-20,ymax=20, ls="--", color="green")
fig.autofmt_xdate()
# Out:
# 2023-11-15 04:01:00
# 2023-11-15 12:12:00
# 2023-11-16 20:22:00
# 2023-11-18 05:42:00
# 2023-11-18 10:43:00
# 2023-11-18 22:33:00
# 2023-11-19 08:34:00
# 2023-11-19 22:12:00
# 2023-11-20 07:06:00
# 2023-11-20 07:33:00
# 2023-11-20 09:03:00
# 2023-11-20 10:14:00
# 2023-11-20 12:31:00
# 2023-11-21 01:18:00
# 2023-11-21 03:45:00
# 2023-11-21 13:52:00
# 2023-11-21 23:40:00
# 2023-11-22 01:11:00
# 2023-11-22 06:28:00
# 2023-11-22 16:45:00
# 2023-11-22 20:26:00
# 2023-11-23 00:03:00
# 2023-11-23 03:38:00
# 2023-11-23 05:44:00
# 2023-11-23 07:14:00
# 2023-11-23 13:15:00
# 2023-11-23 14:37:00
# 2023-11-23 15:38:00
# 2023-11-23 19:21:00
# 2023-11-23 20:39:00
# 2023-11-23 21:05:00
# 2023-11-24 09:33:00
# 2023-11-24 10:42:00
# 2023-11-24 22:19:00
# 2023-11-25 14:39:00
# 2023-11-26 07:44:00
# 2023-11-27 08:11:00
# 2023-11-27 18:52:00
# 2023-11-27 23:39:00
# 2023-11-28 19:50:00
# 2023-11-28 23:31:00
# 2023-11-29 08:03:00
# 2023-11-29 14:35:00

# %%
fig.savefig(datapath+"caso1.png",dpi=500)

# %% [markdown]
# ### filtrando solo data de día

# %%
# unique days
uniquedays = vlfdata["DateTime"].dt.normalize().unique()

# %%
uniquedays
# Out:
# <DatetimeArray>
# ['2023-11-02 00:00:00', '2023-11-03 00:00:00', '2023-11-04 00:00:00',
#  '2023-11-05 00:00:00', '2023-11-06 00:00:00', '2023-11-07 00:00:00',
#  '2023-11-08 00:00:00', '2023-11-09 00:00:00', '2023-11-10 00:00:00',
#  '2023-11-11 00:00:00', '2023-11-12 00:00:00', '2023-11-13 00:00:00',
#  '2023-11-14 00:00:00', '2023-11-15 00:00:00']
# Length: 14, dtype: datetime64[ns]

# %%
# finding flares during local time day
t1 = 11
t2 = 23
flares_tday = []
flares_duringlocalday = pd.DataFrame()
for d in uniquedays:
    flares_tday += list(flares_t[(d+np.timedelta64(t1,"h")<flares_t) & (flares_t< d+np.timedelta64(24,"h"))])
    #df = 
flares_tday = pd.to_datetime(flares_tday)

# %%
flaresdf_localday = pd.DataFrame()
t1 = 11
t2 = 23
for d in uniquedays:
    print(d)
    idx = flaresdf.index[(d+np.timedelta64(t1,"h")<flaresdf["DateTime"]) & (flaresdf["DateTime"]< d+np.timedelta64(t2,"h"))]
    df = flaresdf.loc[idx]
    #print(df.head())
    flaresdf_localday = pd.concat([flaresdf_localday,df])
# Out:
# 2023-11-02 00:00:00
# 2023-11-03 00:00:00
# 2023-11-04 00:00:00
# 2023-11-05 00:00:00
# 2023-11-06 00:00:00
# 2023-11-07 00:00:00
# 2023-11-08 00:00:00
# 2023-11-09 00:00:00
# 2023-11-10 00:00:00
# 2023-11-11 00:00:00
# 2023-11-12 00:00:00
# 2023-11-13 00:00:00
# 2023-11-14 00:00:00
# 2023-11-15 00:00:00

# %%
flaresdf_localday
# Out:
#                 DateTime  GOES-16_short  GOES-16_long
# 679  2023-11-02 11:19:00   3.590106e-07      0.000004
# 742  2023-11-02 12:22:00   3.282921e-06      0.000017
# 1161 2023-11-02 19:21:00   1.357711e-06      0.000010
# 1370 2023-11-02 22:50:00   3.172593e-07      0.000004
# 1358 2023-11-03 22:38:00   3.578387e-07      0.000003
# 703  2023-11-05 11:43:00   3.304830e-06      0.000018
# 872  2023-11-05 14:32:00   3.635696e-06      0.000017
# 1062 2023-11-05 17:42:00   4.708867e-07      0.000004
# 1294 2023-11-05 21:34:00   1.317587e-06      0.000009
# 842  2023-11-06 14:02:00   3.756459e-07      0.000004
# 1213 2023-11-08 20:13:00   4.280350e-07      0.000004
# 734  2023-11-10 12:14:00   2.155090e-07      0.000003
# 964  2023-11-10 16:04:00   3.156198e-07      0.000003
# 756  2023-11-11 12:36:00   1.859992e-07      0.000003
# 1049 2023-11-11 17:29:00   1.387784e-06      0.000013
# 1110 2023-11-11 18:30:00   7.969541e-07      0.000008

# %%
flares_t = pd.to_datetime(flares_t)

# %%
#%matplotlib qt
# %matplotlib inline

# %%
fig, axs = plt.subplots(len(uniquedays[:-1]), 1, figsize=(14,18), sharey=True)
mu = 1e6
delta = np.timedelta64(30, 'm')
twinxs = []

day_hstart = 9
day_hend = 23
fmt = DateFormatter("%H:%M") 
for ii,day in enumerate(uniquedays[:-1]):
    print(day)
    tvlf = vlfdata["DateTime"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))]
    tvlf = tvlf.dt.hour + tvlf.dt.minute/60 + tvlf.dt.second/3600
    la, = axs[ii].plot(tvlf, 
             vlfdata["NAA"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))] , 
             )
    
    axs[ii].text(0.8,0.2, str(day.date()),transform=axs[ii].transAxes )
    tax = axs[ii].twinx()
    twinxs.append(tax)
    axs[ii].set_ylim(-23,23)
    #tax.plot(xrdata["DateTime"][(day+np.timedelta64(day_hstart,'h')<xrdata["DateTime"]) & (xrdata["DateTime"]<day+np.timedelta64(day_hend,'h'))], 
    #         mu * xrdata["GOES-16_long"][(day+np.timedelta64(day_hstart,'h')<xrdata["DateTime"]) & (xrdata["DateTime"]<day+np.timedelta64(day_hend,'h'))] , 
    #         color= "firebrick", label="18_long")
    trx = xrdata["DateTime"][(day+np.timedelta64(day_hstart,'h')<xrdata["DateTime"]) & (xrdata["DateTime"]<day+np.timedelta64(day_hend,'h'))]
    trx = trx.dt.hour + trx.dt.minute/60 + trx.dt.second/3600
    lxr, = tax.plot(trx, 
             mu * xrdata["GOES-16_long"][(day+np.timedelta64(day_hstart,'h')<xrdata["DateTime"]) & (xrdata["DateTime"]<day+np.timedelta64(day_hend,'h'))] , 
             color= "darkorange", label="16_long")
    #tax.legend(loc=1)
    #print(type(day), )
    tax.set_yscale("log")
    tax.set_ylim(0.5,150)
    
    #xx =axs[ii].set_xlim(day+np.timedelta64(day_hstart), day+np.timedelta64(day_hend))
    #print(xx)
    #minloc = AutoMinorLocator(5)
    #tax.yaxis.set_minor_locator(minloc)
    #axs[ii].xaxis.set_major_formatter(fmt)
    for ft in flaresdf["DateTime"].values:
        #if ft.astype("datetime64[D]") == day:
        if (day+np.timedelta64(day_hstart,'h')<ft) & \
            (ft<day+np.timedelta64(day_hend,'h')):
            tt = pd.Timestamp(ft)
            tt = tt.hour+tt.minute/60+tt.second/3600
            lf =tax.axvspan(tt-5/60, 
                        tt+5/60, 
                        alpha=0.2, color="lightcoral")
            #print(ft)
    axs[ii].grid(axis='x', linestyle = ":")
#axs[-1].xaxis.set_major_formatter(fmt)
twinxs[0].get_shared_y_axes().join(*twinxs)            
plt.subplots_adjust(hspace=0)
axs[-1].set_xlabel("Hora (UT)")
#fig.autofmt_xdate(rotation=0,ha="center")
axs[1].set_ylabel("Amplitud (dB)")
twinxs[1].set_ylabel("Flujo de Rayos X ($\mu W/m^2$)")
#plt.lege
plt.legend((la,lxr,lf), ('VLF',"X-ray Fux", "Flare"),bbox_to_anchor=(0.47, -0.4), ncol=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 fig, axs = plt.subplots(len(uniquedays[:-1]), 1, figsize=(14,18), sharey=True)
#       2 mu = 1e6
#       3 delta = np.timedelta64(30, 'm')
#
# NameError: name 'uniquedays' is not defined

# %%
vlfdata["DateTime"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))]
# Out:
# Series([], Name: DateTime, dtype: datetime64[ns])

# %%
vlfdata
# Out:
#             NWC       NPM        JJI       NAA        NLK        NLM  \
# 0     -4.133636 -2.102016 -12.066951  6.657418 -11.356432 -13.092483
# 1     -4.197850 -2.008059 -12.007452  6.500192 -11.743398 -13.275255
# 2     -4.262064 -1.914102 -11.947952  6.342966 -12.130364 -13.458027
# 3     -4.326279 -1.820145 -11.888452  6.185740 -12.517330 -13.640799
# 4     -4.390493 -1.726187 -11.828953  6.028514 -12.904296 -13.823571
# ...         ...       ...        ...       ...        ...        ...
# 94109 -4.839173 -7.371179  -8.867039  4.215637  -3.962896 -10.185599
# 94110 -4.941916 -7.228033  -9.155905  4.318973  -4.092685 -10.426887
# 94111 -5.044659 -7.084887  -9.444772  4.422308  -4.222475 -10.668174
# 94112 -5.147401 -6.941741  -9.733638  4.525644  -4.352265 -10.909461
# 94113 -5.250144 -6.798595 -10.022504  4.628979  -4.482055 -11.150749
#
#                  DateTime
# 0     2023-11-02 16:07:15
# 1     2023-11-02 16:07:24
# 2     2023-11-02 16:07:34
# 3     2023-11-02 16:07:43
# 4     2023-11-02 16:09:49
# ...                   ...
# 94109 2023-11-15 17:57:10
# 94110 2023-11-15 17:57:19
# 94111 2023-11-15 17:57:29
# 94112 2023-11-15 17:57:38
# 94113 2023-11-15 17:57:48
#
# [94114 rows x 7 columns]

# %%
fig.savefig(os.getcwd()+'/XXX_localday_flaresobserved_juni0.png', dpi=300)#datapath

# %%
vlfdata["DateTime"].dt.second
# Out:
# 0        15
# 1        24
# 2        34
# 3        43
# 4        49
#          ..
# 94109    10
# 94110    19
# 94111    29
# 94112    38
# 94113    48
# Name: DateTime, Length: 94114, dtype: int32

# %%
fig = plt.figure(figsize=(12,6))
for ii, day in enumerate(uniquedays):
    tx = vlfdata["DateTime"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))]
    th = tx.dt.hour + tx.dt.minute/60 + tx.dt.second/3600
    plt.plot(th, 
             vlfdata["NAA"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))] , label="")

# %%
fig.savefig("superpuestas.png", dpi=600)

# %%
dts = np.diff(vlfdata["DateTime"].iloc[100:])/np.timedelta64(1,'s')
plt.subplot(211)
plt.plot(vlfdata["DateTime"].iloc[10:50], "o")
plt.subplot(212)
plt.plot(dts[:50], marker="s", markerfacecolor="none")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 dts = np.diff(vlfdata["DateTime"].iloc[100:])/np.timedelta64(1,'s')
#       2 plt.subplot(211)
#       3 plt.plot(vlfdata["DateTime"].iloc[10:50], "o")
#
# NameError: name 'vlfdata' is not defined

# %%
dts/np.timedelta64(1, 's')
# Out:
# array([10.,  9.,  9., ..., 10.,  9., 10.])

# %% [markdown]
# # QUIET DAYS:

# %%
def to_stddt(t, tref=dt.date.today()):
    '''t : array of time elements
        tref: reference date
    Returnds: datetime
    '''
    
    y =[dt.datetime.combine(tref, x) for x in t]
    return np.asarray(y)



qdays = [np.datetime64("2023-11-07"), np.datetime64("2023-11-03")]

x = len(vlfdata["DateTime"][(qdays[0]<vlfdata["DateTime"]) & (vlfdata["DateTime"]<qdays[0]+np.timedelta64(24,'h'))]) 
quiet_day = np.zeros(x)
for ii, d in enumerate(qdays):
    quiet_day += vlfdata["NAA"][(d<vlfdata["DateTime"]) & (vlfdata["DateTime"]<d+np.timedelta64(24,'h'))].values
quiet_day /= len(qdays)

t = vlfdata["DateTime"][(d<vlfdata["DateTime"]) & 
                                (vlfdata["DateTime"]<d+np.timedelta64(24,'h'))]
th = t.dt.time.values
th_quiet_day = to_stddt(th) 
fig = plt.figure()
plt.plot(th_quiet_day, quiet_day)
#plt.plot(th, vlfdata["NAA"][(d<vlfdata["DateTime"]) & 
#                                (vlfdata["DateTime"]<d+np.timedelta64(24,'h'))].values)
#plt.show()
fig.autofmt_xdate()

# %%
th_quiet_day = pd.Series([pd.Timestamp(x) for x in th_quiet_day])

# %%
tref_h = th_quiet_day.dt.hour + th_quiet_day.dt.minute/60 + th_quiet_day.dt.second/3600

# %% [markdown]
# # Finding perturbations

# %%
delta_obs = np.timedelta64(30,'m')
delta_flare = np.timedelta64(10,'m')

# %% [markdown]
# ## Match between VLF and XRays Flux

# %%
abs(np.array([4,5,7-2]))
# Out:
# array([4, 5, 5])

# %%
def nearest_dt(target, dtv):
    '''target is an array or single value (to find)
    dtv is the array to look/search in 
    '''# dtv is the array to look/search in 
    if len(target)==1:
        return np.argmin(abs(np.asarray(dtv)-target))
    else:
        return np.asarray([np.argmin(abs(dtv-t)) for t in target])

# %%
flares_index_invlf = nearest_dt(flaresdf_localday["DateTime"], vlfdata["DateTime"])

# %%
flares_index_invlf
# Out:
# array([    0,     0,   924,  1969,  9109, 20234, 21079, 22028, 23188,
#        28129, 44394, 56399, 57548, 63709, 65174, 65479])

# %%
plt.rcParams['legend.handlelength'] = 0
plt.rcParams['font.size'] = 12

# %% [markdown]
# There are dome index to delete yet from flares_index_invlf

# %%
#flares_index_invlf = np.asarray(flares_index_invlf)

# %%
fig = plt.figure( figsize=(10,10))

fmt = DateFormatter("%H:%M")    
axs[-1].xaxis.set_major_formatter(fmt)

for ii, k in enumerate(flares_index_invlf):
    ax = plt.subplot(5,5, ii+1)
    t0 = vlfdata["DateTime"].iloc[k]
    print(t0)
    mask = (vlfdata["DateTime"]>t0 - delta_obs) & (vlfdata["DateTime"]<t0+delta_obs)
    t = vlfdata["DateTime"].loc[mask]
    amp = vlfdata["NAA"].loc[mask]
    
    plt.plot(t, amp, label=t0.strftime("%d-%m %H:%M"))
    plt.legend(fontsize=10, markerscale=0,numpoints=1)
    ax.set_xticks([t0 - delta_obs,t0,t0 + delta_obs])
    ax.set_xticklabels(["$t_0$-{}'".format(delta_obs/np.timedelta64(60,'m')),"$t_0$", "$t_0$+{}'".format( delta_obs/np.timedelta64(60,'m')) ],fontsize=11)
    ax.vlines(t0, -5,10, linestyle=":", color="coral", alpha=1)
    #ax.axes.xaxis.set_visible(False)
    #fmt = DateFormatter("%H:%M:%S")    
    #ax.xaxis.set_major_formatter(fmt)
# Out:
# 2023-11-02 16:07:15
# 2023-11-02 16:07:15
# 2023-11-02 19:21:10
# 2023-11-02 22:50:10
# 2023-11-03 22:38:10
# 2023-11-05 11:43:10
# 2023-11-05 14:32:11
# 2023-11-05 17:41:49
# 2023-11-05 21:33:48
# 2023-11-06 14:02:11
# 2023-11-08 20:13:10
# 2023-11-10 12:14:11
# 2023-11-10 16:03:48
# 2023-11-11 12:36:11
# 2023-11-11 17:29:11
# 2023-11-11 18:30:10

# %%
flares_index_invlf
# Out:
# array([    0,     0,   924,  1969,  9109, 20234, 21079, 22028, 23188,
#        28129, 44394, 56399, 57548, 63709, 65174, 65479])

# %%
def h_from_timestamp(dt):
    dt = pd.T(dt)
    th = dt.dt.hour + dt.dt.minute/60 + dt.dt.second/3600 
    return th

def match_hours(t0, tv):
    """
    returns ii which is the closest element index of tv to t0
    """
    tvh = tv.dt.hour + tv.dt.minute/60 + tv.dt.second/3600 
    t0h = t0.hour + t0.minute/60 + t0.second/3600
    ii = np.argmin(abs(tvh-t0h))
    return ii

# %%
delta_obs = np.timedelta64(50,'m')

fig = plt.figure( figsize=(10,10))
pdelta = []
fmt = DateFormatter("%H:%M")    
axs[-1].xaxis.set_major_formatter(fmt)
deltas = []
for ii, k in enumerate(flares_index_invlf):
    ax = plt.subplot(6,6, ii+1)
    t0 = vlfdata["DateTime"].iloc[k]
    t0_h = t0.hour+t0.minute/60+t0.second/3600
    delta_obs_h = delta_obs/np.timedelta64(1,'h')
    print(t0)
    t0_ = t0.time
    mask = (vlfdata["DateTime"]>t0 - delta_obs) & (vlfdata["DateTime"]<t0+delta_obs)
    mask_loc = (vlfdata["DateTime"]>t0 - delta_flare) & (vlfdata["DateTime"]<t0+delta_flare)
    t = vlfdata["DateTime"].loc[mask]
    amp = vlfdata["NAA"].loc[mask].values
    t0h = t.dt.hour + t.dt.minute/60 + t.dt.second/3600
    plt.plot(t0h, amp, label=t0.strftime("%d-%m %H:%M"))
    plt.legend(fontsize=10, markerscale=0,numpoints=1)
    ax.set_xticks([t0_h - delta_obs_h,t0_h,t0_h + delta_obs_h])
    ax.set_xticklabels(["$t_0$-{}'".format(delta_obs.astype(int)),"$t_0$", "$t_0$+{}'".format( delta_obs.astype(int)) ],fontsize=11)
    ax.vlines(t0_h, -5,10, linestyle=":", color="coral", alpha=1)
    # local max
    mask = (tref_h>t0_h - delta_obs_h) & (tref_h<t0_h+delta_obs_h)
    #t = vlfdata["DateTime"].loc[mask]
    plt.plot(tref_h[mask],quiet_day[mask])
    #amp = vlfdata["NAA"].loc[mask].values
    amp = vlfdata["NAA"].loc[mask_loc].values
    im = np.argmax(amp)
    locmax = amp[im]
    pert = amp[im]
    ci = match_hours(t0, th_quiet_day)
    a0 = quiet_day[ci]
    deltas.append(locmax-a0)
    model = np.poly1d(np.polyfit(tref_h[mask], quiet_day[mask], 2))
    ymodel = model(tref_h[mask])
    pdelta.append(pert-ymodel[im])
    plt.plot(tref_h[mask],ymodel, color="c")
    ax.set_xticks([t0_h - delta_obs_h,t0_h,t0_h + delta_obs_h])
    plt.scatter(t0_h, locmax,edgecolors="r",c="none", marker="s",s=50,linewidths=2)
    plt.scatter(t0_h, a0, edgecolors="b",c="none", marker="s",s=50,linewidths=2)
    #ax.axes.xaxis.set_visible(False)
    #fmt = DateFormatter("%H:%M:%S")    
    #ax.xaxis.set_major_formatter(fmt)
# Out:
# 2023-11-02 16:07:15
# 2023-11-02 16:07:15
# 2023-11-02 19:21:10
# 2023-11-02 22:50:10
# 2023-11-03 22:38:10
# 2023-11-05 11:43:10
# 2023-11-05 14:32:11
# 2023-11-05 17:41:49
# 2023-11-05 21:33:48
# 2023-11-06 14:02:11
# 2023-11-08 20:13:10
# 2023-11-10 12:14:11
# 2023-11-10 16:03:48
# 2023-11-11 12:36:11
# 2023-11-11 17:29:11
# 2023-11-11 18:30:10

# %%
#flares_index_invlf = [flares_index_invlf[0]] #np.delete(flares_index_invlf, [])
flares_index_invlf = flares_index_invlf[[3 ,6,7,10,]]

# %%
flares_index_invlf
# Out:
# array([ 9342, 23762, 26450, 32606])

# %%
delta_obs = np.timedelta64(50,'m')

fig = plt.figure( figsize=(8,6))

fmt = DateFormatter("%H:%M")    
axs = []
deltas = []
pdelta = []
for ii, k in enumerate(flares_index_invlf):
    ax = plt.subplot(2,2, ii+1)
    t0 = vlfdata["DateTime"].iloc[k]
    t0_h = t0.hour+t0.minute/60+t0.second/3600
    delta_obs_h = delta_obs/np.timedelta64(1,'h')
    print(t0)
    t0_ = t0.time()
    mask = (vlfdata["DateTime"]>t0 - delta_obs) & (vlfdata["DateTime"]<t0+delta_obs)
    mask_loc = (vlfdata["DateTime"]>t0 - delta_flare) & (vlfdata["DateTime"]<t0+delta_flare)
    t = vlfdata["DateTime"].loc[mask]
    amp = vlfdata["NAA"].loc[mask].values
    t0h = t.dt.hour + t.dt.minute/60 + t.dt.second/3600
    plt.plot(t0h, amp, label=t0.strftime("%d-%m %H:%M"))
    plt.legend(fontsize=10, markerscale=0,numpoints=1)
    ax.set_xticks([t0_h - delta_obs_h,t0_h,t0_h + delta_obs_h])
    ax.set_xticklabels(["$t_0$-{}'".format(delta_obs.astype(int)),"$t_0$", "$t_0$+{}'".format( delta_obs.astype(int)) ],fontsize=11)
    ax.vlines(t0_h, -5,10, linestyle=":", color="coral", alpha=1)
    # local max
    mask = (tref_h>t0_h - delta_obs_h) & (tref_h<t0_h+delta_obs_h)
    #t = vlfdata["DateTime"].loc[mask]
    plt.plot(tref_h[mask],quiet_day[mask])
    #amp = vlfdata["NAA"].loc[mask].values
    amp = vlfdata["NAA"].loc[mask_loc].values
    im = np.argmax(amp)
    locmax = amp[im]
    ci = match_hours(t0, th_quiet_day)
    a0 = quiet_day[ci]
    deltas.append(locmax-a0)
    model = np.poly1d(np.polyfit(tref_h[mask], quiet_day[mask], 2))
    ymodel = model(tref_h[mask])
    
    plt.plot(tref_h[mask],ymodel, color="c")
    plt.scatter(t0_h, locmax,edgecolors="r",c="none", marker="s",s=50,linewidths=2)
    plt.scatter(t0_h, a0, edgecolors="b",c="none", marker="s",s=50,linewidths=2)
    pdelta.append(locmax-a0)
    #ax.axes.xaxis.set_visible(False)
    #fmt = DateFormatter("%H:%M:%S")    
    #ax.xaxis.set_major_formatter(fmt)
    axs.append(ax)
fig.text(0.05,0.5,"Amplitude (dB)",rotation="vertical")
#axs[-1].set_xlabel("time (UT)", loc="right")
fig.text(0.35,0.03, "Time relative to flare peak (UT)")
# Out:
# 2023-10-07 18:06:15
# 2023-10-09 11:43:10
# 2023-10-09 19:11:11
# 2023-10-10 12:17:11
# Text(0.35, 0.03, 'Time relative to flare peak (UT)')

# %%
k
# Out:
# 32606

# %%
flares_index_inrx = nearest_dt(vlfdata["DateTime"].iloc[flares_index_invlf], flaresdf_localday["DateTime"] )

# %%
vlfdata["DateTime"].loc[flares_index_invlf]
# Out:
# 9342    2023-10-07 18:06:15
# 23762   2023-10-09 11:43:10
# 26450   2023-10-09 19:11:11
# 32606   2023-10-10 12:17:11
# Name: DateTime, dtype: datetime64[ns]

# %%
flares = [vlfdata["DateTime"].iloc[flares_index_invlf].values, 
          np.array(pdelta).T, 
          flaresdf_localday["DateTime"].iloc[flares_index_inrx].values, 
          flaresdf_localday["GOES-16_long"].iloc[flares_index_inrx].values]
flares = np.asarray(flares)
flares.T
# Out:
# array([[1696701975000000000, 1.525939147434526, 1696701960000000000,
#         1.7912622e-05],
#        [1696851790000000000, 3.3087995510699795, 1696851780000000000,
#         7.6201563e-06],
#        [1696878671000000000, 2.939240937605536, 1696878660000000000,
#         9.230462e-06],
#        [1696940231000000000, 3.7787574475676617, 1696940220000000000,
#         2.3474566e-05]], dtype=object)

# %%
flarescorr = pd.DataFrame(flares.T, columns=["UT_VLF", "delta_dB","UT_XR", "XRF"])

# %%
flarescorr
# Out:
#                 UT_VLF  delta_dB                UT_XR       XRF
# 0  1696701975000000000  1.525939  1696701960000000000  0.000018
# 1  1696851790000000000    3.3088  1696851780000000000  0.000008
# 2  1696878671000000000  2.939241  1696878660000000000  0.000009
# 3  1696940231000000000  3.778757  1696940220000000000  0.000023

# %%
flarescorr["UT_VLF"] = pd.to_datetime(flarescorr["UT_VLF"])
flarescorr["UT_XR"] = pd.to_datetime(flarescorr["UT_XR"])

# %%
flarescorr
# Out:
#                UT_VLF  delta_dB               UT_XR       XRF
# 0 2023-10-07 18:06:15  1.525939 2023-10-07 18:06:00  0.000018
# 1 2023-10-09 11:43:10    3.3088 2023-10-09 11:43:00  0.000008
# 2 2023-10-09 19:11:11  2.939241 2023-10-09 19:11:00  0.000009
# 3 2023-10-10 12:17:11  3.778757 2023-10-10 12:17:00  0.000023

# %%
plt.plot(flarescorr["XRF"], flarescorr["delta_dB"], 's',markersize=10)

# %%
flarescorr.to_csv("perturbations_{}--{}.csv".format(vlfdata["DateTime"].min(), vlfdata["DateTime"].max()))

# %% [markdown]
# ### Correspoding $\Delta XRF$

# %%
iindxs = nearest_dt(t_pert, flaresdf_localday["Tiempo Universal"])

# %%
plt.plot(flaresdf_localday["GOES-17_long"].iloc[iindxs], pert_vals, 's',markersize=10)

# %%
# finding peaks -> explosions
c = 1e6
peaks, x = signal.find_peaks(xrdata["GOES-17_long"].values*c,rel_height=10,distance=5, prominence=10)


fig = plt.figure(figsize=(12, 6))


plt.plot(xrdata['Tiempo Universal'], xrdata["GOES-17_long"]*c)
plt.scatter(xrdata['Tiempo Universal'].iloc[peaks], xrdata["GOES-17_long"].iloc[peaks]*c, marker='s', c="dodgerblue",label="Explosion detectada")
plt.scatter(flaresdf_localday['Tiempo Universal'].iloc[iindxs], flaresdf_localday["GOES-17_long"].iloc[iindxs]*c, marker='s', c="red",label="Explosion detectada")
fig.autofmt_xdate()

# C class flare region
plt.axhspan(1e-6*c,1e-5*c, color="yellow", alpha=0.3, label="Tipo C")
plt.axhspan(1e-5*c,1e-4*c, color="orange", alpha=0.3, label="Tipo M")
plt.axhspan(1e-4*c, 1.5*max(xrdata["GOES-17_long"])*c , color="red", alpha=0.3, label="Tipo X")
#plt.axhspan(1e-5,1e-5, color="yellow", alpha=0.3)
l = plt.legend(framealpha=1,facecolor='whitesmoke')
for l_ in l.legendHandles:
    l_._legmarker.set_markersize(6)
plt.ylabel("Flujo de Rayos X ($\mu Wm^{-2}$)")
plt.xlabel("Tiempo (Año-Mes-Día)")
plt.ylim(-2,120)
plt.xlim()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-258-ccf9adc6d1ac> in <module>
#       9 plt.plot(xrdata['Tiempo Universal'], xrdata["GOES-17_long"]*c)
#      10 plt.scatter(xrdata['Tiempo Universal'].iloc[peaks], xrdata["GOES-17_long"].iloc[peaks]*c, marker='s', c="dodgerblue",label="Explosion detectada")
# ---> 11 plt.scatter(flaresdf_localday['Tiempo Universal'].iloc[iindxs], flaresdf_localday["GOES-17_long"].iloc[iindxs]*c, marker='s', c="red",label="Explosion detectada")
#      12 fig.autofmt_xdate()
#      13
#
# NameError: name 'iindxs' is not defined

# %%
o=0

# %%
np
# Out:
# <module 'numpy' from '/home/aldo/pavnet_notebooks/pavnetenv/lib/python3.6/site-packages/numpy/__init__.py'>

# %% [markdown]
# # I need a Daily variatiuon of the VLF

# %%
day_hstart = 0
day_hend = 24

fig, axs = plt.subplots(len(uniquedays), 1, figsize=(12,10), sharey=True)
mu = 1e6
delta = np.timedelta64(30, 'm')
twinxs = []


for ii,day in enumerate(uniquedays):
    axs[ii].plot(vlfdata["DateTime"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))], 
             vlfdata["NAA"][(day+np.timedelta64(day_hstart,'h')<vlfdata["DateTime"]) & (vlfdata["DateTime"]<day+np.timedelta64(day_hend,'h'))] , 
             zorder=1, color="darkblue")
    axs[ii].plot(timevdn[(day+np.timedelta64(day_hstart,'h')<timevdn) & (timevdn<day+np.timedelta64(day_hend,'h'))], 
             dndatadb["NAA"][(day+np.timedelta64(day_hstart,'h')<timevdn) & (timevdn<day+np.timedelta64(day_hend,'h'))] , 
             zorder=0, marker='o', alpha=0.3,  color="lightgray")
    axs[ii].text(0.8,0.2, np.datetime_as_string(day,"D"),transform=axs[ii].transAxes )
    
    print(axs[ii].get_xlim())
    #tax = axs[ii].twinx()
    #twinxs.append(tax)
    
    #tax.plot(xrdata["Tiempo Universal"][(day+np.timedelta64(day_hstart,'h')<xrdata["Tiempo Universal"]) & (xrdata["Tiempo Universal"]<day+np.timedelta64(day_hend,'h'))], 
    #         mu * xrdata["GOES-17_long"][(day+np.timedelta64(day_hstart,'h')<xrdata["Tiempo Universal"]) & (xrdata["Tiempo Universal"]<day+np.timedelta64(day_hend,'h'))] , 
    #         color= "firebrick")
    #print(type(day), )
    #tax.set_yscale("log")
    #tax.set_ylim(1,1000)
    axs[ii].grid(axis='x', linestyle = ":")
    #lbls = [itm.get_text() for itm in tax.get_xticklabels()]
    #lbls[0] = None
    #tax.set_xticklabels(lbls)
    #for ft in flares_t.values:
    #    #if ft.astype("datetime64[D]") == day:
    #    if (day+np.timedelta64(day_hstart,'h')<ft) & \
    #        (ft<day+np.timedelta64(day_hend,'h')):
    #        tax.axvspan(ft-np.timedelta64(5,"m"), 
    #                    ft+np.timedelta64(5,"m"), 
    #                    alpha=0.2, color="lightcoral")
fmt = DateFormatter("%H:%M")    
axs[-1].xaxis.set_major_formatter(fmt)
            

axs[-1].set_xlabel("Hora (UT)")
fig.autofmt_xdate(rotation=0,ha="center")
axs[3].set_ylabel("Amplitud (dB)")
#twinxs[3].set_ylabel("Flujo de Rayos X ($\mu W/m^2$)")
axs[-1].axes.xaxis.set_minor_locator(MultipleLocator(3))
axs[-1].set_xlim(19234.950104166666+1, 19236.049849537038+1)
plt.tick_params(axis='x', which='minor', bottom=True)
plt.tight_layout()
plt.subplots_adjust(hspace=0)
axs[-1].set_ylim(-15,15)
# Out:
# (19229.950116898148, 19231.049836805556)
# (19230.95010474537, 19232.04983738426)
# (19231.95009201389, 19233.04985011574)
# (19232.950116898148, 19234.049836805556)
# (19233.950104166666, 19235.049849537038)
# (19234.950104166666, 19236.049849537038)
# (19235.95132349537, 19237.02424363426)
# (-15.0, 15.0)

# %%
datapath
# Out:
# '/data/Datos_PLO/PLO_250822-010922'

# %%
fig.savefig(datapath+"/dn_NAA_24h_260822-010922_rawandsavgol.png", dpi=300)

# %%
dndatadb.head()
# Out:
#          NWC        NPM        JJI        NAA        NLK        NLM
# 0 -59.398942 -67.182225 -66.156444 -65.400513 -66.061312 -64.965599
# 1  -0.837407   5.906655  -7.611368   6.674414  -1.560238  -1.190406
# 2   0.365779   6.093640  -6.741510   6.925561  -1.078238   0.949010
# 3  -1.307442   7.214048  -7.017894   6.691720  -0.786560  -0.325256
# 4  -2.282114   6.310740  -6.248962   5.471593  -0.370364  -0.138271

# %%
timevdn
# Out:
# array([datetime.datetime(2022, 8, 6, 10, 12, 42),
#        datetime.datetime(2022, 8, 6, 10, 13, 7),
#        datetime.datetime(2022, 8, 6, 10, 13, 13), ...,
#        datetime.datetime(2022, 9, 1, 23, 24, 28),
#        datetime.datetime(2022, 9, 1, 23, 24, 34),
#        datetime.datetime(2022, 9, 1, 23, 24, 41)], dtype=object)

# %%
meas_flares = pd.read_csv(datapath+"/tab_flares.csv")

# %%
meas_flares
# Out:
#     Unnamed: 0     Tiempo (UT)  Amp_0  Amp_1  XRF_0  XRF_1  delta_{VLF}  \
# 0            0  26/08/22 12:14   0.23   6.54    2.1   73.0         6.31
# 1            1  26/08/22 12:31   5.93   7.17   30.3   55.3         1.24
# 2            2  26/08/22 13:16   5.03   7.05   25.5   36.7         2.01
# 3            3  27/08/22 11:38   2.41   4.16    3.5    8.8         1.75
# 4            4  27/08/22 12:48   3.53   5.26    3.3    9.5         1.73
# 5            5  27/08/22 13:13   0.72   2.42    3.5   11.9         1.75
# 6            6  27/08/22 15:25   4.91   7.56    3.5   10.8         2.64
# 7            7  27/08/22 15:58   5.68   8.53    3.7   18.5         2.84
# 8            8  28/08/22 16:18   5.25   8.99    3.5   67.8         3.74
# 9            9  28/08/22 18:32   7.85   9.88   16.6   47.4         2.03
# 10          10  29/08/22 11:07   1.29   4.15    6.1   84.9         2.86
#
#     delta_{XRflux}
# 0             70.9
# 1             24.9
# 2             11.2
# 3              5.3
# 4              6.2
# 5              8.4
# 6              7.3
# 7             14.8
# 8             64.3
# 9             30.7
# 10            78.8

# %%
meas_flares["delta_vlfamp"] = meas_flares["Amp_1"]-meas_flares["Amp_0"]
meas_flares["delta_rxflux"] = meas_flares["XRF_1"]-meas_flares["XRF_0"]

# %%
x, y = meas_flares["delta_rxflux"].sort_values() , meas_flares["delta_vlfamp"].sort_values()

# %%
x = np.asarray(x)
y = np.asarray(y)

# %%
fig = plt.figure()
#plt.plot(x,y)
plt.scatter(x,y, s = 80)

# %%
#%matplotlib inline

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x.reshape(-1,1), y.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_pred = model.intercept_ + model.coef_ * x

# %%
fig = plt.figure(figsize=(8,6))
#plt.plot(x,y)
plt.scatter(x,y, s = 80, c="blue")
plt.plot(x, y_pred.reshape(-1,1), color="r", label="$R²=%.2f$"%model.score(x.reshape(-1,1),y.reshape(-1,1)))
plt.legend(loc=4)
plt.xlabel("$\Delta\Phi_{X-Rays} \quad (\mu Wm^{-2})$")
plt.ylabel("$\Delta A_{VLF} \quad (dB)$")
#plt.xscale("log")
# Out:
# Text(0, 0.5, '$\\Delta A_{VLF} \\quad (dB)$')

# %%
fig.savefig(datapath+"/correlation_vlf_xrf.png", dpi=300)

# %%
meas_flares.to_csv(datapath+"/tab_flares.csv")

# %% [markdown]
# ### log scale

# %%
xlogs = np.log10(x)

# %%
modellog = LinearRegression()

# %%
modellog.fit(xlogs.reshape(-1,1), y.reshape(-1,1))
# Out:
# LinearRegression()

# %%
y_log_pred = modellog.intercept_ + modellog.coef_ * xlogs

# %%
plt.rcParams["font.size"]=16
fig = plt.figure(figsize=(8,6))
#plt.plot(x,y)
plt.scatter(xlogs,y, s = 80, c="blue")
plt.plot(xlogs, y_log_pred.reshape(-1,1), color="r", label="$R²=%.2f$"%model.score(x.reshape(-1,1),y.reshape(-1,1)))
plt.legend(loc=4)
plt.xlabel("$\Delta\Phi_{X-Rays} \quad (\mu Wm^{-2})$")
plt.ylabel("$\Delta A_{VLF} \quad (dB)$")
#plt.xscale("symlog")
#plt.xlim(1,10)
# Out:
# Text(0, 0.5, '$\\Delta A_{VLF} \\quad (dB)$')

# %% [markdown]
# ## DELTA H with NPM

# %%
vlfdata
# Out:
#              NWC       NPM        JJI       NAA        NLK        NLM  \
# 0      -4.085903  0.763003 -13.200257  4.755472 -10.330838  -5.056950
# 1      -3.811732  0.968231 -12.799373  4.897108  -9.906221  -4.822381
# 2      -3.551245  1.163430 -12.409951  5.031414  -9.501244  -4.599388
# 3      -3.304442  1.348600 -12.031990  5.158389  -9.115908  -4.387971
# 4      -3.071323  1.523741 -11.665492  5.278032  -8.750212  -4.188131
# ...          ...       ...        ...       ...        ...        ...
# 109285 -4.233080  7.704511  -0.305932 -3.866032  -4.481108 -12.198512
# 109286 -4.194328  8.183530  -0.375713 -3.962732  -4.400942 -12.763690
# 109287 -4.148720  8.669149  -0.448586 -4.061816  -4.315417 -13.346874
# 109288 -4.096255  9.161369  -0.524552 -4.163284  -4.224534 -13.948066
# 109289 -4.036933  9.660189  -0.603609 -4.267136  -4.128293 -14.567264
#
#                   DateTime
# 0      2023-02-23 15:11:06
# 1      2023-02-23 15:11:11
# 2      2023-02-23 15:11:15
# 3      2023-02-23 15:11:20
# 4      2023-02-23 15:11:24
# ...                    ...
# 109285 2023-03-06 11:27:11
# 109286 2023-03-06 11:27:16
# 109287 2023-03-06 11:27:20
# 109288 2023-03-06 11:27:25
# 109289 2023-03-06 11:27:29
#
# [109290 rows x 7 columns]

# %%
fig, ax = plt.subplots(nrows=len(uniquedays[1:-1]), figsize=(10, 14), sharex=True)

for k, tday in enumerate(uniquedays[1:-1]):
    
    mask = (vlfdata["DateTime"]<=tday) & (tday<vlfdata["DateTime"] + np.timedelta64(24, 'h'))
    th = vlfdata["DateTime"].loc[mask].dt.second/3600 + vlfdata["DateTime"].loc[mask].dt.minute/60 \
            +vlfdata["DateTime"].loc[mask].dt.hour
    ax[k].plot(th, vlfdata["NPM"].loc[mask], label="{}".format(tday))
    ax[k].axvspan(10, 16, color="yellow", alpha=0.3)
    ax[k].legend()

# %%
vlfdata["DateTime"].loc[mask].dt.hour/601
# Out:
# 0       0.024958
# 1       0.024958
# 2       0.024958
# 3       0.024958
# 4       0.024958
#           ...
# 3628    0.038270
# 3629    0.038270
# 3630    0.038270
# 3631    0.038270
# 3632    0.038270
# Name: DateTime, Length: 3633, dtype: float64
