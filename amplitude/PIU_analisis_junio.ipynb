# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import sys
import datetime as dt

# %%
data = pd.read_csv("/data/pavnet/2025/PIURA/PIU_AMPLITUDE_2025-05-27-to-2025-06-30.csv", index_col=[0], parse_dates=[0])

# %%
data.loc[dt.date(2025,5,30):dt.date(2025,5,31) ,"NAA-filt"].plot()
plt.yscale("log")

# %%
dt.datetime(2025,6,10).date()
# Out:
# datetime.date(2025, 6, 10)

# %%
data
# Out:
#                           NPM       NAA       NLK       NLM       NAU  \
# 2025-05-27 04:59:55  2.033112  1.225287  1.095584  0.953430  0.000007
# 2025-05-27 05:00:05  1.898389  1.260591  1.119154  1.057768  0.000008
# 2025-05-27 05:00:14  1.919327  1.313622  1.008482  0.940169  0.000006
# 2025-05-27 05:00:24  1.893351  1.154364  0.971239  1.053898  0.000005
# 2025-05-27 05:00:34  1.981652  1.187955  0.982414  0.950546  0.000011
# ...                       ...       ...       ...       ...       ...
# 2025-06-30 11:30:56  2.331563  1.168407  0.695184  0.430180  0.000009
# 2025-06-30 11:31:06  2.448539  1.248292  0.545753  0.508296  0.000012
# 2025-06-30 11:31:16  2.383422  1.284827  0.547637  0.485187  0.000009
# 2025-06-30 11:31:26  2.411293  1.140912  0.483219  0.406398  0.000010
# 2025-06-30 11:31:35  2.325129  1.031850  0.549970  0.515769  0.000006
#
#                      NPM-filt  NAA-filt  NLK-filt  NLM-filt  NAU-filt
# ...
